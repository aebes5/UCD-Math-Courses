# %%
import pyomo.environ as pyo

model = pyo.ConcreteModel()

#decision variables
model.x1 = pyo.Var(domain=pyo.NonNegativeReals)
model.x2 = pyo.Var(domain=pyo.NonNegativeReals)

#objective function
def obj_rule(model):
    return 100*model.x1 + 150*model.x2

model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)


#constraints
def first(model):
    return (8000*model.x1 + 4000*model.x2) <= 40000

model.first_const = pyo.Constraint(rule=first)

def second(model):
    return (15*model.x1 + 30*model.x2) <= 200

model.second_const = pyo.Constraint(rule=second)

result = pyo.SolverFactory("gurobi").solve(model, tee=True)

# Solution
print(f'The solver returned a status of: {result.solver.termination_condition}')

# Solution
if result.solver.termination_condition == pyo.TerminationCondition.optimal:
    print(pyo.TerminationCondition.optimal)
    print(f"Optimal value: {pyo.value(model.obj)}")
    print("Optimal solution:")
    print(f"  x1: {pyo.value(model.x1)}")
    print(f"  x2: {pyo.value(model.x2)}")
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Read LP format model from file C:\Users\Andre\AppData\Local\Temp\tmpzsfczhvy.pyomo.lp
# Reading time = 0.00 seconds
# x1: 2 rows, 2 columns, 4 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 9 4900HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2 rows, 2 columns and 4 nonzeros
# Model fingerprint: 0x8c581e3f
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [2e+01, 8e+03]
#   Objective range  [1e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 4e+04]
# Found heuristic solution: objective 500.0000000
# Presolve time: 0.01s
# Presolved: 2 rows, 2 columns, 4 nonzeros
# Variable types: 0 continuous, 2 integer (0 binary)
# Found heuristic solution: objective 550.0000000
#
# ...

# %%
import pyomo.environ as pyo

model = pyo.ConcreteModel()

#decision variables
model.x1 = pyo.Var(domain=pyo.NonNegativeReals, bounds = (0,2))
model.x2 = pyo.Var(domain=pyo.NonNegativeReals)

#objective function
def obj_rule(model):
    return 100*model.x1 + 150*model.x2

model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)


#constraints
def first(model):
    return (8000*model.x1 + 4000*model.x2) <= 40000

model.first_const = pyo.Constraint(rule=first)

def second(model):
    return (15*model.x1 + 30*model.x2) <= 200

model.second_const = pyo.Constraint(rule=second)

result = pyo.SolverFactory("gurobi").solve(model, tee=True)

# Solution
print(f'The solver returned a status of: {result.solver.termination_condition}')

# Solution
if result.solver.termination_condition == pyo.TerminationCondition.optimal:
    print(pyo.TerminationCondition.optimal)
    print(f"Optimal value: {pyo.value(model.obj)}")
    print("Optimal solution:")
    print(f"  x1: {pyo.value(model.x1)}")
    print(f"  x2: {pyo.value(model.x2)}")
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Read LP format model from file C:\Users\Andre\AppData\Local\Temp\tmpy2o50bu6.pyomo.lp
# Reading time = 0.01 seconds
# x1: 2 rows, 2 columns, 4 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 9 4900HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2 rows, 2 columns and 4 nonzeros
# Model fingerprint: 0x2ae2f8cd
# Coefficient statistics:
#   Matrix range     [2e+01, 8e+03]
#   Objective range  [1e+02, 2e+02]
#   Bounds range     [2e+00, 2e+00]
#   RHS range        [2e+02, 4e+04]
# Presolve time: 0.00s
# Presolved: 2 rows, 2 columns, 4 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3437500e+30   1.914063e+30   2.343750e+00      0s
#        2    1.0500000e+03   0.000000e+00   0.000000e+00      0s
#
# ...

# %%
import pyomo.environ as pyo

model = pyo.ConcreteModel()

#decision variables
model.x1 = pyo.Var(domain=pyo.NonNegativeReals, bounds = (0,2))
model.x2 = pyo.Var(domain=pyo.NonNegativeReals, bounds = (0,5))

#objective function
def obj_rule(model):
    return 100*model.x1 + 150*model.x2

model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)


#constraints
def first(model):
    return (8000*model.x1 + 4000*model.x2) <= 40000

model.first_const = pyo.Constraint(rule=first)

def second(model):
    return (15*model.x1 + 30*model.x2) <= 200

model.second_const = pyo.Constraint(rule=second)

result = pyo.SolverFactory("gurobi").solve(model, tee=True)

# Solution
print(f'The solver returned a status of: {result.solver.termination_condition}')

# Solution
if result.solver.termination_condition == pyo.TerminationCondition.optimal:
    print(pyo.TerminationCondition.optimal)
    print(f"Optimal value: {pyo.value(model.obj)}")
    print("Optimal solution:")
    print(f"  x1: {pyo.value(model.x1)}")
    print(f"  x2: {pyo.value(model.x2)}")
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Read LP format model from file C:\Users\Andre\AppData\Local\Temp\tmp90p21gv5.pyomo.lp
# Reading time = 0.01 seconds
# x1: 2 rows, 2 columns, 4 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 9 4900HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2 rows, 2 columns and 4 nonzeros
# Model fingerprint: 0x7cffedac
# Coefficient statistics:
#   Matrix range     [2e+01, 8e+03]
#   Objective range  [1e+02, 2e+02]
#   Bounds range     [2e+00, 5e+00]
#   RHS range        [2e+02, 4e+04]
# Presolve removed 2 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.5000000e+02   0.000000e+00   0.000000e+00      0s
#
# ...

# %%
import pyomo.environ as pyo

model = pyo.ConcreteModel()

#decision variables
model.x1 = pyo.Var(domain=pyo.NonNegativeReals, bounds = (0,2))
model.x2 = pyo.Var(domain=pyo.NonNegativeReals, bounds = (6,None))

#objective function
def obj_rule(model):
    return 100*model.x1 + 150*model.x2

model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)


#constraints
def first(model):
    return (8000*model.x1 + 4000*model.x2) <= 40000

model.first_const = pyo.Constraint(rule=first)

def second(model):
    return (15*model.x1 + 30*model.x2) <= 200

model.second_const = pyo.Constraint(rule=second)

result = pyo.SolverFactory("gurobi").solve(model, tee=True)

# Solution
print(f'The solver returned a status of: {result.solver.termination_condition}')

# Solution
if result.solver.termination_condition == pyo.TerminationCondition.optimal:
    print(pyo.TerminationCondition.optimal)
    print(f"Optimal value: {pyo.value(model.obj)}")
    print("Optimal solution:")
    print(f"  x1: {pyo.value(model.x1)}")
    print(f"  x2: {pyo.value(model.x2)}")
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Read LP format model from file C:\Users\Andre\AppData\Local\Temp\tmpv4l7mm73.pyomo.lp
# Reading time = 0.01 seconds
# x1: 2 rows, 2 columns, 4 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 9 4900HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2 rows, 2 columns and 4 nonzeros
# Model fingerprint: 0xd8bf5371
# Coefficient statistics:
#   Matrix range     [2e+01, 8e+03]
#   Objective range  [1e+02, 2e+02]
#   Bounds range     [2e+00, 6e+00]
#   RHS range        [2e+02, 4e+04]
# Presolve removed 2 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0333333e+03   0.000000e+00   0.000000e+00      0s
#
# ...

# %%
import pyomo.environ as pyo

model = pyo.ConcreteModel()

#decision variables
model.x1 = pyo.Var(domain=pyo.NonNegativeReals, bounds = (0,1))
model.x2 = pyo.Var(domain=pyo.NonNegativeReals, bounds = (6,None))

#objective function
def obj_rule(model):
    return 100*model.x1 + 150*model.x2

model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)


#constraints
def first(model):
    return (8000*model.x1 + 4000*model.x2) <= 40000

model.first_const = pyo.Constraint(rule=first)

def second(model):
    return (15*model.x1 + 30*model.x2) <= 200

model.second_const = pyo.Constraint(rule=second)

result = pyo.SolverFactory("gurobi").solve(model, tee=True)

# Solution
print(f'The solver returned a status of: {result.solver.termination_condition}')

# Solution
if result.solver.termination_condition == pyo.TerminationCondition.optimal:
    print(pyo.TerminationCondition.optimal)
    print(f"Optimal value: {pyo.value(model.obj)}")
    print("Optimal solution:")
    print(f"  x1: {pyo.value(model.x1)}")
    print(f"  x2: {pyo.value(model.x2)}")
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Read LP format model from file C:\Users\Andre\AppData\Local\Temp\tmp28cv4n8x.pyomo.lp
# Reading time = 0.00 seconds
# x1: 2 rows, 2 columns, 4 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 9 4900HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2 rows, 2 columns and 4 nonzeros
# Model fingerprint: 0x60ae6ab3
# Coefficient statistics:
#   Matrix range     [2e+01, 8e+03]
#   Objective range  [1e+02, 2e+02]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [2e+02, 4e+04]
# Presolve removed 2 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0250000e+03   0.000000e+00   0.000000e+00      0s
#
# ...

# %%
import pyomo.environ as pyo

model = pyo.ConcreteModel()

#decision variables
model.x1 = pyo.Var(domain=pyo.NonNegativeReals, bounds = (0,1))
model.x2 = pyo.Var(domain=pyo.NonNegativeReals, bounds = (6,6))

#objective function
def obj_rule(model):
    return 100*model.x1 + 150*model.x2

model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)


#constraints
def first(model):
    return (8000*model.x1 + 4000*model.x2) <= 40000

model.first_const = pyo.Constraint(rule=first)

def second(model):
    return (15*model.x1 + 30*model.x2) <= 200

model.second_const = pyo.Constraint(rule=second)

result = pyo.SolverFactory("gurobi").solve(model, tee=True)

# Solution
print(f'The solver returned a status of: {result.solver.termination_condition}')

# Solution
if result.solver.termination_condition == pyo.TerminationCondition.optimal:
    print(pyo.TerminationCondition.optimal)
    print(f"Optimal value: {pyo.value(model.obj)}")
    print("Optimal solution:")
    print(f"  x1: {pyo.value(model.x1)}")
    print(f"  x2: {pyo.value(model.x2)}")
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Read LP format model from file C:\Users\Andre\AppData\Local\Temp\tmp1yol0go1.pyomo.lp
# Reading time = 0.01 seconds
# x1: 2 rows, 2 columns, 4 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 9 4900HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2 rows, 2 columns and 4 nonzeros
# Model fingerprint: 0x7aa1cd75
# Coefficient statistics:
#   Matrix range     [2e+01, 8e+03]
#   Objective range  [1e+02, 2e+02]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [2e+02, 4e+04]
# Presolve removed 2 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+03   0.000000e+00   0.000000e+00      0s
#
# ...

# %%
import pyomo.environ as pyo

model = pyo.ConcreteModel()

#decision variables
model.x1 = pyo.Var(domain=pyo.NonNegativeReals, bounds = (0,1))
model.x2 = pyo.Var(domain=pyo.NonNegativeReals, bounds = (7,None))

#objective function
def obj_rule(model):
    return 100*model.x1 + 150*model.x2

model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)


#constraints
def first(model):
    return (8000*model.x1 + 4000*model.x2) <= 40000

model.first_const = pyo.Constraint(rule=first)

def second(model):
    return (15*model.x1 + 30*model.x2) <= 200

model.second_const = pyo.Constraint(rule=second)

result = pyo.SolverFactory("gurobi").solve(model, tee=True)

# Solution
print(f'The solver returned a status of: {result.solver.termination_condition}')

# Solution
if result.solver.termination_condition == pyo.TerminationCondition.optimal:
    print(pyo.TerminationCondition.optimal)
    print(f"Optimal value: {pyo.value(model.obj)}")
    print("Optimal solution:")
    print(f"  x1: {pyo.value(model.x1)}")
    print(f"  x2: {pyo.value(model.x2)}")
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Read LP format model from file C:\Users\Andre\AppData\Local\Temp\tmpuedb6vnr.pyomo.lp
# Reading time = 0.01 seconds
# x1: 2 rows, 2 columns, 4 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 9 4900HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2 rows, 2 columns and 4 nonzeros
# Model fingerprint: 0x93a5bcea
# Coefficient statistics:
#   Matrix range     [2e+01, 8e+03]
#   Objective range  [1e+02, 2e+02]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [2e+02, 4e+04]
# Presolve time: 0.00s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Infeasible or unbounded model
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasibleOrUnbounded
# ...

# %%
import pyomo.environ as pyo

model = pyo.ConcreteModel()

#decision variables
model.x1 = pyo.Var(domain=pyo.NonNegativeReals, bounds = (2,2))
model.x2 = pyo.Var(domain=pyo.NonNegativeReals, bounds = (6,None))

#objective function
def obj_rule(model):
    return 100*model.x1 + 150*model.x2

model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)


#constraints
def first(model):
    return (8000*model.x1 + 4000*model.x2) <= 40000

model.first_const = pyo.Constraint(rule=first)

def second(model):
    return (15*model.x1 + 30*model.x2) <= 200

model.second_const = pyo.Constraint(rule=second)

result = pyo.SolverFactory("gurobi").solve(model, tee=True)

# Solution
print(f'The solver returned a status of: {result.solver.termination_condition}')

# Solution
if result.solver.termination_condition == pyo.TerminationCondition.optimal:
    print(pyo.TerminationCondition.optimal)
    print(f"Optimal value: {pyo.value(model.obj)}")
    print("Optimal solution:")
    print(f"  x1: {pyo.value(model.x1)}")
    print(f"  x2: {pyo.value(model.x2)}")
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Read LP format model from file C:\Users\Andre\AppData\Local\Temp\tmpf6qvm7_4.pyomo.lp
# Reading time = 0.01 seconds
# x1: 2 rows, 2 columns, 4 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 9 4900HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2 rows, 2 columns and 4 nonzeros
# Model fingerprint: 0x17130ff9
# Coefficient statistics:
#   Matrix range     [2e+01, 8e+03]
#   Objective range  [1e+02, 2e+02]
#   Bounds range     [2e+00, 6e+00]
#   RHS range        [2e+02, 4e+04]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Infeasible or unbounded model
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
# ...

# %%
import pyomo.environ as pyo

model = pyo.ConcreteModel()

#decision variables
model.x1 = pyo.Var(domain=pyo.NonNegativeReals, bounds = (3,None))
model.x2 = pyo.Var(domain=pyo.NonNegativeReals)

#objective function
def obj_rule(model):
    return 100*model.x1 + 150*model.x2

model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)


#constraints
def first(model):
    return (8000*model.x1 + 4000*model.x2) <= 40000

model.first_const = pyo.Constraint(rule=first)

def second(model):
    return (15*model.x1 + 30*model.x2) <= 200

model.second_const = pyo.Constraint(rule=second)

result = pyo.SolverFactory("gurobi").solve(model, tee=True)

# Solution
print(f'The solver returned a status of: {result.solver.termination_condition}')

# Solution
if result.solver.termination_condition == pyo.TerminationCondition.optimal:
    print(pyo.TerminationCondition.optimal)
    print(f"Optimal value: {pyo.value(model.obj)}")
    print("Optimal solution:")
    print(f"  x1: {pyo.value(model.x1)}")
    print(f"  x2: {pyo.value(model.x2)}")
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Read LP format model from file C:\Users\Andre\AppData\Local\Temp\tmpvsphd7ft.pyomo.lp
# Reading time = 0.01 seconds
# x1: 2 rows, 2 columns, 4 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 9 4900HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2 rows, 2 columns and 4 nonzeros
# Model fingerprint: 0x6015adc8
# Coefficient statistics:
#   Matrix range     [2e+01, 8e+03]
#   Objective range  [1e+02, 2e+02]
#   Bounds range     [3e+00, 3e+00]
#   RHS range        [2e+02, 4e+04]
# Presolve removed 2 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.0000000e+02   0.000000e+00   0.000000e+00      0s
#
# ...
