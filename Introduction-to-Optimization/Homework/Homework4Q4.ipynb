# %%
#PROBLEM 4c

import pyomo.environ as pyo

model = pyo.ConcreteModel()

#decision variables
model.x1 = pyo.Var(domain=pyo.NonNegativeReals)
model.x2 = pyo.Var(domain=pyo.NonNegativeReals)
model.x3 = pyo.Var()

#objective function
def obj_rule(model):
    return 30*model.x1 - 100*model.x2 - 40*model.x3

model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)


#constraints
def rule_one(model):
    return (3*model.x1 + 10*model.x2 + 5*model.x3) <= 40

model.rule_one_const = pyo.Constraint(rule=rule_one)

def rule_two(model):
    return (model.x1 + model.x2 + model.x3) >= 7

model.rule_two_const = pyo.Constraint(rule=rule_two)

def rule_three(model):
    return (model.x1 + 2*model.x2 + 2*model.x3) == 10

model.rule_three_const = pyo.Constraint(rule=rule_three)

result = pyo.SolverFactory("gurobi").solve(model, tee=True)



# Solution
print(f'The solver returned a status of: {result.solver.termination_condition}')

# Solution
if result.solver.termination_condition == pyo.TerminationCondition.optimal:
    print(pyo.TerminationCondition.optimal)
    print(f"Optimal value: {pyo.value(model.obj)}")
    print("Optimal solution:")
    print(f"  x1: {pyo.value(model.x1)}")
    print(f"  x2: {pyo.value(model.x2)}")    
    print(f"  x3: {pyo.value(model.x3)}")
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Read LP format model from file C:\Users\Andre\AppData\Local\Temp\tmpw1ammn8i.pyomo.lp
# Reading time = 0.00 seconds
# x1: 3 rows, 3 columns, 9 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 9 4900HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x72576dde
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+00, 4e+01]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3000000e+03   0.000000e+00   0.000000e+00      0s
#
# ...

# %%
#PROBLEM 4c

import pyomo.environ as pyo

model = pyo.ConcreteModel()

#decision variables
model.x1 = pyo.Var(domain=pyo.NonNegativeReals)
model.x2 = pyo.Var(domain=pyo.NonNegativeReals)
model.x3 = pyo.Var()
model.u1 = pyo.Var(domain=pyo.NonNegativeReals)
model.v1 = pyo.Var(domain=pyo.NonNegativeReals)
model.s1 = pyo.Var(domain=pyo.NonNegativeReals)
model.s2 = pyo.Var(domain=pyo.NonNegativeReals)

#objective function
def obj_rule(model):
    return 30*model.x1 - 100*model.x2 - 40*(model.u1 - model.v1)

model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)


#constraints
def rule_one(model):
    return (3*model.x1 + 10*model.x2 + 5*(model.u1 - model.v1) + model.s1) == 40

model.rule_one_const = pyo.Constraint(rule=rule_one)

def rule_two(model):
    return (model.x1 + model.x2 + (model.u1 - model.v1) - model.s2) == 7

model.rule_two_const = pyo.Constraint(rule=rule_two)

def rule_three(model):
    return (model.x1 + 2*model.x2 + 2*(model.u1 - model.v1)) == 10

model.rule_three_const = pyo.Constraint(rule=rule_three)

result = pyo.SolverFactory("gurobi").solve(model, tee=True)



# Solution
print(f'The solver returned a status of: {result.solver.termination_condition}')


# Solution
if result.solver.termination_condition == pyo.TerminationCondition.optimal:
    print(pyo.TerminationCondition.optimal)
    print(f"Optimal value: {pyo.value(model.obj)}")
    print("Optimal solution:")
    print(f"  x1: {pyo.value(model.x1)}")
    print(f"  x2: {pyo.value(model.x2)}")    
    print(f"  x3: {pyo.value((model.u1 - model.v1))}")
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Read LP format model from file C:\Users\Andre\AppData\Local\Temp\tmpwu_lwfu2.pyomo.lp
# Reading time = 0.01 seconds
# x1: 3 rows, 6 columns, 14 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 9 4900HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3 rows, 6 columns and 14 nonzeros
# Model fingerprint: 0x5624ca63
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+00, 4e+01]
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3000000e+03   0.000000e+00   0.000000e+00      0s
#
# ...

# %%
#PROBLEM 4c

import pyomo.environ as pyo

model = pyo.ConcreteModel()

#decision variables
model.x1 = pyo.Var(domain=pyo.NonNegativeReals)
model.x2 = pyo.Var(domain=pyo.NonNegativeReals)
model.x3 = pyo.Var()
model.u1 = pyo.Var(domain=pyo.NonNegativeReals)
model.v1 = pyo.Var(domain=pyo.NonNegativeReals)

#objective function
def obj_rule(model):
    return -30*model.x1 + 100*model.x2 + 40*(model.u1 - model.v1)

model.obj = pyo.Objective(rule=obj_rule, sense=pyo.minimize)


#constraints
def rule_one(model):
    return (-3*model.x1 - 10*model.x2 - 5*(model.u1 - model.v1)) >= -40

model.rule_one_const = pyo.Constraint(rule=rule_one)

def rule_two(model):
    return (model.x1 + model.x2 + (model.u1 - model.v1)) >= 7

model.rule_two_const = pyo.Constraint(rule=rule_two)

def rule_three(model):
    return (model.x1 + 2*model.x2 + 2*(model.u1 - model.v1)) == 10

model.rule_three_const = pyo.Constraint(rule=rule_three)

result = pyo.SolverFactory("gurobi").solve(model, tee=True)



# Solution
print(f'The solver returned a status of: {result.solver.termination_condition}')


# Solution
if result.solver.termination_condition == pyo.TerminationCondition.optimal:
    print(pyo.TerminationCondition.optimal)
    print(f"Optimal value: {pyo.value(model.obj)}")
    print("Optimal solution:")
    print(f"  x1: {pyo.value(model.x1)}")
    print(f"  x2: {pyo.value(model.x2)}")    
    print(f"  x3: {pyo.value((model.u1 - model.v1))}")
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Read LP format model from file C:\Users\Andre\AppData\Local\Temp\tmpzbrhmpch.pyomo.lp
# Reading time = 0.01 seconds
# x1: 3 rows, 4 columns, 12 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 9 4900HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x15a2d5a2
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+00, 4e+01]
# Presolve removed 3 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.3000000e+03   0.000000e+00   0.000000e+00      0s
#
# ...
