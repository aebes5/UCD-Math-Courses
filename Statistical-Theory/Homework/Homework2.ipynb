# %% [markdown]
# # Homework 2: Due Wednesday, January 31 at 11:00AM
#
# ---

# %% [markdown]
# ## <a name="HW1Inst">Instructions:</a>
# ---
#
# 1. <font color="tomato">Either click the COPY TO DRIVE button or use the menu File/Save/Save a Copy to save your own version of the notebook in your own folder in Google Drive.</font>
#
#   - If you do not have a Google account, you will need to create a Google account in order to create your own individual copy of this notebook.
#   - By default, the notebook will be saved in a folder named **Colab Notebooks** in your drive.
#   - Feel free to name and store the notebook wherever you like!
#
# 2. <font color="mediumseagreen">After you have copied the notebook into your Drive, you can begin editing and saving your work.</font>
#
# **Upload your completed assignment into Canvas as a Google Colab (or Jupyter) Notebook with file extension `.ipynb`.**
#
# Upload your file into the Homework 2 assignment in Canvas before <font color="dodgerblue">**11AM on Wednesday, January 31.**</font>
#
# **You must provide supporting work for your all of your answers.**
#
#   - <font color="dodgerblue">That work will include using R code cells.</font>
#     - **Feel free to insert as much R code as you like.**
#     - You must interpret or explain how the output of a code cell is being utilized to solve the problem.
#     - **Code with incomplete or missing explanations of why the output is useful may not receive full credit.**
#   - <font color="dodgerblue">Your work will also involve writing explanations and justifications in text cells.</font>
#     - **Be sure to type/write out the steps of your work/explanation so I can see how you arrived at your answer.**
#
#
# ## Important Academic Policies:
# ---
#
# - **Be your own work.** Though you may collaborate with others, everyone is responsible for writing up the work in their own way using their own methods. Plagiarism of any form is not tolerated.
# - **Be complete.** You must provide all work and/or explanations needed to find the solution. Answers with insufficient or incomplete supporting work may lose credit.
# - **Adhere to the Code of Academic Honesty.**
# - **Be clearly written (and legible if written).** Your solution to a problem must be clear, written in complete sentences. You may lose credit for work that is unclear or hard to follow.
#
# ## <font color="dodgerblue">Let me know if you need help, and **GOOD LUCK!!!**</font>
#
# ----

# %% [markdown]
# # <a name="hw2q1">Question 1</a>
#
# ---
#
# In the code cell below, we load a data frame called `insurance` that can be analyzed for insurance forecasting based on various features. The original data set was downloaded in comma-separated values (.csv) format from Kaggle<sup>1</sup>. Run the code cell below before answering the parts of this question.
#
# <br>
#
# <font size="2">1. Choi, Miri. Medical Cost Personal Datasets. Retrieved January 12, 2023 from <https://www.kaggle.com/data sets/mirichoi0218/insurance>.</font>

# %%
# Run this code cell to import data as data frame
insurance <- read.csv(file = "https://raw.githubusercontent.com/CU-Denver-MathStats-OER/Statistical-Theory/main/Data/insurance.csv",
                  header = TRUE,
                  sep = ",",)

# Some Data Wrangling to Help Clean the Data
insurance$sex <- factor(insurance$sex)
insurance$smoker <- factor(insurance$smoker)
insurance$region <- factor(insurance$region)

# %% [markdown]
# ### Data Dictionary
#
# Interesting features include BMI, Number of Children, and if the person is a smoker or not.
#
# -   `age`: age of primary beneficiary
# -   `sex`: gender of primary beneficiary assigned at birth
# -   `bmi`: Body mass index of primary beneficiary
# -   `children`: Number of children covered by health insurance of primary beneficiary
# -   `smoker`: Does primary beneficiary smoke cigarettes.
# -   `region`: the beneficiary's residential area in the US.
# -   `charges`: Medical costs billed by health insurance to the primary beneficiary

# %% [markdown]
# ## <a name="hw2q1a">Question 1a</a>
#
# ---
#
# In this question, you can pick any **categorical variable** of interest in `insurance`. Choose whichever one you like. Answer the following questions regarding the categorical variable you selected:
#
# -   What are the classes? What proportion of the observations are in each class?
# -   Give at least one plot that gives a visual summary of the distribution of the observations in the data.
#     -   **Extra beautiful plots are a bonus!**
#     -   For example, try (not required) adding a title, labels to axes, color, legend, etc if they are helpful. This is not required.
#     -   Recall you can enter `?plot`, `?barplot`, `?table`, `?prop.table`, etc. for help documentation for a command which often summarizes possible options.
#     -   [See Overview of Plotting Help Document](https://aspiegler.github.io/Statistical-Theory/Overview-of-Plots.html) for examples with code of displaying different types of variables.
#
#
#
# ### Solution to Question 1a
#
# ---
#
# Use the code cells below to answer the questions above.
#
# <br>

# %%
# display the proportion of observations in each class
# categorical variable is sex: classes are male and female
# male (676 / 1338), female (662 / 1338)
table(insurance$sex)
# Out:
# female   male
#    662    676

# %%
# create at least one plot that gives a visual summary
plot(insurance$sex,
        main = "Distribution of Gender in the Dataset",
        xlab = "Gender",
        ylab = "Count",
        col = c("pink", "steelblue"),
        legend = TRUE)
# Out:
# Plot with title “Distribution of Gender in the Dataset”

# %% [markdown]
# ## <a name="hw2q1b">Question 1b</a>
#
# ---
#
# After looking at the numerical/graphical summaries of the variable [Question 1a](#hw2q1a):
#
# -   **Comment on any interesting, unexpected, and/or confusing features of the variable that you observe.**
# -   **What interesting questions might there be for further investigation?**
#
# ### Solution to Question 1b
#
# ---
# There's not anything interesting with the sex variable I chose; I probably chose the most boring variable as the proportion of male and female are nearly indentical. Something interesting that could be asked is how the male/females were selected during this study and why there isn't a 1:1 ratio between them. Also, is this enough data from each sex to make conclusions.
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="hw2q1c">Question 1c</a>
#
# ---
#
# In this question, you can pick any **quantitative variable** of interest in `insurance`. Choose whichever one you like. Then similar to [Question 1a](#hw2q1a), answer the following questions regarding the quantitative variable you selected:
#
# -   What are the mean, standard deviation, and five number summary of the variable?
# -   Give at least one plot that gives a visual summary of the distribution of the observations in the data.
#     -   **Extra beautiful plots are a bonus!**
#     -   See links in [Question 1a](#hw1q1a) for help with plotting.
#
# ### Solution to Question 1c
#
# ---
#
# #### Numerical Summary:
#
# Replace each ?? with an appropriate value. If needed, round answers to two decimal places.
#
# -   The mean is 39.21.
# -   The standard deviation is 14.05.
# -   The five number summary is (18, 27, 39, 51, 64).
#
# <br>
#
# #### Graphical Summary
#
# Use the code cell below to answer the question.
#
# <br>

# %%
# find numerical summary of a quantitative variable
# quantitative variable is age
mean(insurance$age)
sd(insurance$age)
fivenum(insurance$age)
# Out:
# [1] 39.20703
# [1] 14.04996
# [1] 18 27 39 51 64

# %%
# create at least one plot that gives a visual summary
boxplot(insurance$age,
        main = "Distribution of Age in the Dataset",
        xlab = "Age",
        ylab = "Count",
        col = "steelblue",
        legend = TRUE)
hist(insurance$age,
        main = "Distribution of Age in the Dataset",
        xlab = "Age",
        ylab = "Count",
        col = "steelblue",
        legend = TRUE)
# Out:
# Warning message in plot.window(xlim, ylim, "", ...):
# “"legend" is not a graphical parameter”
# Warning message in title(main = main, sub = sub, xlab = xlab, ylab = ylab, ...):
# “"legend" is not a graphical parameter”
# Warning message in axis(1, ...):
# “"legend" is not a graphical parameter”
# Warning message in axis(2, at = yt, ...):
# “"legend" is not a graphical parameter”
# Plot with title “Distribution of Age in the Dataset”
# Plot with title “Distribution of Age in the Dataset”

# %% [markdown]
# ## <a name="hw2q1d">Question 1d</a>
#
# ---
#
#
# After looking at the numerical/graphical summaries of the variable in [Question 1c](#hw2q1c):
#
# -  **What is the shape (skewness) of the data?**
# -   **Comment on any interesting, unexpected, and/or confusing features of the variable that you observe.**
# -   **What interesting questions might there be for further investigation?**
#
#
# ### Solution to Question 1d
#
# ---
# The data is symmetric and it's interesting that each age range has roughly the same amount of people - aside from those under 20 and over 60. It seems interesting the most amount of people were the 10-20 considering that age has just begin driving. One question I would ask is if there was a cut off for age participants they chose considering there was nobody over 70 and I know people 70+ that drive. Where was this data collected?
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="hw2q1e">Question 1e</a>
#
# ---
#
# **Subset or filter** the data to create a new data frame that includes **only the health policies of the non-smokers**. Then create a bar chart to display the number of non-smoker policies in each region.
#
# -   **Extra beautiful plots are a bonus!**
# -   See links in [Question 1a](#hw2q1a) for help with plotting.
#
# ### Solution to Question 1e
#
# ---
#
# Complete the code cells below to answer the question.
#
# <br>

# %%
# Use this code cell to subset or filter data
# insurance$smoker
sub <- subset(insurance, smoker == "no")
plot(sub$region,
        main = "Distribution of Non-smokers by Region",
        xlab = "Region",
        ylab = "Count",
        col = "steelblue",
        legend = TRUE)
# Out:
# Plot with title “Distribution of Non-smokers by Region”

# %% [markdown]
# ## <a name="hw2q1f">Question 1f</a>
#
# ---
#
# In which `region` is the average bmi of the primary beneficiary greatest? In which region is the average bmi smallest?
#
# -   Hint: The `tapply` function is one nice way to answer this question.
#     -   Enter `?tapply` for the help documentation.
#     -   This may be a useful source with examples: <https://www.statology.org/tapply-r/>
#
# - You do not need to use `tapply`. Feel free to answer however you like!
#
# ### Solution to Question 1f
#
# ---
#
# Use the code cell below to answer the questions. After looking at the output of your code, type your answers below.
#
# - The region with greatest average bmi is southeast
# - The region with smallest average bmi is northeast
#
#
# Be sure to provide code and relevant output that you used to help answer the question below.
#
# <br>

# %%
# use code cell to answer question 1f
tapply(insurance$bmi, insurance$region, mean)
# Out:
# northeast northwest southeast southwest
#  29.17350  29.19978  33.35599  30.59662

# %% [markdown]
# ## <a name="hw2q1g">Question 1g</a>
#
# ---
#
# Create side-by-side boxplots (on the same set of axes) to compare the total medical costs billed (variable named `charges`) for smokers compared to non-smokers.
#
# -   **Extra beautiful plots are a bonus!**
# -   For example, label each boxplot to be sure it is clear which boxplot corresponds to which class.
# -   See links in [Question 1a](#hw2q1a) for help with plotting.
#
#
# ### Solution to Question 1g
#
# ---
#
# Use the code cell below to create side-by-side boxplots.
#
# <br>

# %%
# create side-by-side boxplots
ggplot(insurance, aes(x = smoker, y = charges, fill = smoker)) +
  geom_boxplot() +
  labs(title = "Medical costs for Smokers and Non-smokers",
       x = "Smoker",
       y = "Charges")
# Out:
# plot without title

# %% [markdown]
# ## <a name="hw2q1h">Question 1h</a>
#
# ---
#
# Create a stacked relative frequency bar chart to compare the proportion of smokers/non-smokers in each region to help answer the [Question 1i](#hw2q1i) below:
#
# > Which region seems to have the greatest proportion of smokers?
#
# -   Be sure your plot is easy to read. For example,
#   - Include titles on both axes.
#   - Include a main title to describe the plot.
#   - Include a legend or some way to make it clear which stack color corresponds to which class.
# -   Have I mentioned, **extra beautiful plots are a bonus!**
# -   See links in [Question 1a](#hw2q1a) for help with plotting.
#
#
#
# ### Solution to Question 1h
#
# ---
#
# Use the code cell below to create your plot.
#
# <br>

# %%
# create a stacked bar chart
plot(table(insurance$region, insurance$smoker) /
  rowSums(table(insurance$region, insurance$smoker)),
        main = "Proportion of Smokers by Region",
        xlab = "Region",
        ylab = "Smoker",
        col = "steelblue")
# Out:
# Error in eval(expr, envir, enclos): object 'insurance' not found
# Traceback:
#
# 1. plot(table(insurance$region, insurance$smoker)/rowSums(table(insurance$region,
#  .     insurance$smoker)), main = "Proportion of Smokers by Region",
#  .     xlab = "Region", ylab = "Smoker", col = "steelblue", legend = TRUE)
# 2. table(insurance$region, insurance$smoker)

# %% [markdown]
# ## <a name="hw2q1i">Question 1i</a>
#
# ---
#
# Based on your plot from [Question 1h](#hw2q1h), which region seems to have the greatest proportion of smokers? Explain how you used the plot above to determine your answer.
#
# ### Solution to Question 1i
#
# ---
#
# Type your answer in the space below and be sure to explain how you used the plot above to determine your answer.
#
# The southeast seems to have the greatest proportion of smokers which can be seen visually in the plot above. This is reasonable because each region is individually comparing smokers to non-smokers; so in this case the proportion isn't coming from the total of all regions, but rather the one region. The column under southeast had the greatest 'yes' and lowest 'no' which indicates they have the greatest proportion of smokers.
# <br>
# <br>
# <br>

# %% [markdown]
# # <a name="hw2q2">Question 2</a>
#
# ---
#
# For this problem you will use the data set  `diamonds` in the `ggplot2` package.
#
# <br>
#
# The first code cell below loads the `ggplot2` package that will allow you to access the `diamonds` data frame.
# The second code cell provides a summary of the `diamonds` data frame.
#
# After running the code cells below, answer the questions that follow.

# %%
# load the ggplot2 package
library(ggplot2)

# %%
# numerical summaries of all variables
summary(diamonds)
?diamonds
# Out:
#      carat               cut        color        clarity          depth
#  Min.   :0.2000   Fair     : 1610   D: 6775   SI1    :13065   Min.   :43.00
#  1st Qu.:0.4000   Good     : 4906   E: 9797   VS2    :12258   1st Qu.:61.00
#  Median :0.7000   Very Good:12082   F: 9542   SI2    : 9194   Median :61.80
#  Mean   :0.7979   Premium  :13791   G:11292   VS1    : 8171   Mean   :61.75
#  3rd Qu.:1.0400   Ideal    :21551   H: 8304   VVS2   : 5066   3rd Qu.:62.50
#  Max.   :5.0100                     I: 5422   VVS1   : 3655   Max.   :79.00
#                                     J: 2808   (Other): 2531
#      table           price             x                y
#  Min.   :43.00   Min.   :  326   Min.   : 0.000   Min.   : 0.000
#  1st Qu.:56.00   1st Qu.:  950   1st Qu.: 4.710   1st Qu.: 4.720
#  Median :57.00   Median : 2401   Median : 5.700   Median : 5.710
#  Mean   :57.46   Mean   : 3933   Mean   : 5.731   Mean   : 5.735
#  3rd Qu.:59.00   3rd Qu.: 5324   3rd Qu.: 6.540   3rd Qu.: 6.540
# ...

# %% [markdown]
# ## <a name="hw2q2a">Question 2a</a>
#
# ---
#
# Is this data from a population or a sample? Justify how you determined your answer in a complete sentence in the space below.
#
#
# ### Solution to Question 2a
#
# ---
# This is a sample as there are ~ 54,000 diamonds in this study and I'd be willing to bet there are more than that many diamonds for population.
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="hw2q2b">Question 2b</a>
#
# ---
#
# How many observations are in the data set?
#
# ### Solution to Question 2b
#
# ---
#
# - Use the code cell below to help answer the question.
#
# - Based on the output of the code cell below, write a complete sentence to answer the question in the space below.
#
# There are 53,940 observations in this data set.
# <br>
# <br>
# <br>

# %%
nrow(diamonds)
# Out:
# [1] 53940

# %% [markdown]
# ## <a name="hw2q2c">Question 2c</a>
#
# ---
#
# List all of the categorical variables in the data set, and indicate how many classes (or levels) each categorical variable has.
#
# ### Solution to Question 2c
#
# ---
#
# - Use the code cell below or output from a previous code cell to help answer the question.
#
# - In the space below, list each categorical variable, indicate how many classes (or levels) there are for each, and give the name of each class for each categorical variable.
#
#
# There are three categorical variables: cut, color, and clarity. Cut has 5 classes - fair, good, very good, premium, ideal - color has 7 classes - D, E, F, G, H, I, J - and clarity has 8 classes - I1, SI2, SI1, VS2, VS1, VVS2, VVS1, IF.
#
# <br>
# <br>
# <br>

# %%
# use code cell to answer
str(diamonds)

for (var in c("cut", "color", "clarity")) {
  cat_levels <- table(diamonds[[var]])
  print(paste("Variable:", var))
  print(cat_levels)
}
# Out:
# tibble [53,940 × 10] (S3: tbl_df/tbl/data.frame)
#  $ carat  : num [1:53940] 0.23 0.21 0.23 0.29 0.31 0.24 0.24 0.26 0.22 0.23 ...
#  $ cut    : Ord.factor w/ 5 levels "Fair"<"Good"<..: 5 4 2 4 2 3 3 3 1 3 ...
#  $ color  : Ord.factor w/ 7 levels "D"<"E"<"F"<"G"<..: 2 2 2 6 7 7 6 5 2 5 ...
#  $ clarity: Ord.factor w/ 8 levels "I1"<"SI2"<"SI1"<..: 2 3 5 4 2 6 7 3 4 5 ...
#  $ depth  : num [1:53940] 61.5 59.8 56.9 62.4 63.3 62.8 62.3 61.9 65.1 59.4 ...
#  $ table  : num [1:53940] 55 61 65 58 58 57 57 55 61 61 ...
#  $ price  : int [1:53940] 326 326 327 334 335 336 336 337 337 338 ...
#  $ x      : num [1:53940] 3.95 3.89 4.05 4.2 4.34 3.94 3.95 4.07 3.87 4 ...
#  $ y      : num [1:53940] 3.98 3.84 4.07 4.23 4.35 3.96 3.98 4.11 3.78 4.05 ...
#  $ z      : num [1:53940] 2.43 2.31 2.31 2.63 2.75 2.48 2.47 2.53 2.49 2.39 ...
# [1] "Variable: cut"
#
#      Fair      Good Very Good   Premium     Ideal
#      1610      4906     12082     13791     21551
# [1] "Variable: color"
#
# ...

# %% [markdown]
# ## <a name="hw2q2d">Question 2d</a>
#
# ---
#
# List all of the quantitative variables in the data set.
#
# <br>
#
# - *Note: No need to run additional code since you should be able to identify this answer using output from previous code cells.*
#
# - *No justification needed in your solution below, just list the quantitative variables.*
#
# ### Solution to Question 2d
#
# ---
# The quantitative variables are carat, depth, table, price, x, y, and z.
#
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="hw2q2e">Question 2e
#
# ---
#
# Create table and bar chart of the variable called `cut`.
#
# ### Solution to Question 2e
#
# ---
#
# Enter R code in the cells below. Nothing to explain or interpret.
#
# <br>

# %%
# enter a command to create a table
(cutTab <- table(diamonds$cut))
# Out:
#      Fair      Good Very Good   Premium     Ideal
#      1610      4906     12082     13791     21551

# %%
# enter a command to create a bar chart
plot(diamonds$cut,
     main = "Diamonds by Cut",  # main title
     xlab = "Cut Quality",  # horizontal axis label
     ylab = "Count",  # vertical axis label
     col = "steelblue")
# Out:
# Plot with title “Diamonds by Cut”

# %% [markdown]
# ## <a name="hw2q2f">Question 2f</a>
#
# ---
#
# Create a histogram to display the distribution of values of the variable `price`. The nicer looking the graph, the better!
#
# ### Solution to Question 2f
#
# ---
#
# Enter R code in the cell below. Nothing to explain or interpret.
#
# <br>

# %%
# create a histogram
hist(diamonds$price,
     xlab = "Price(in dollars)",   # x-axis label
     xlim = c(0,20000),  # sets window for x-axis
     ylab = "Frequency",  # y-axis label
     main = "Distribution of Diamonds by Price",  # main label
     cex.lab=1.5, cex.axis=1.5, cex.main=1.5,  # increase font size
     col = "steelblue")
# Out:
# Plot with title “Distribution of Diamonds by Price”

# %% [markdown]
# ## <a name="hw2q2g">Question 2g</a>
#
# ---
#
# Give the five number summary for the variable `price`.
#
#
# ### Solution to Question 2g
#
# ---
#
# - Use the code cell below to help answer.
# - Based on the output below, type your five number summary in the parentheses below:
#
# <br>
#
# (326, 950, 2401, 5324.5, 18823)
#
# <br>
# <br>

# %%
# enter a command to find 5 number summary
fivenum(diamonds$price)
# Out:
# [1]   326.0   950.0  2401.0  5324.5 18823.0

# %% [markdown]
# ## <a name="hw2q2h">Question 2h</a>
#
# ---
#
#
# Create an empirical cumulative distribution function (ecdf) for `price`. Based on the output, approximately what proportion of diamonds in the data have a price greater than or equal to 5000 USD?
#
# ### Solution to Question 2h
#
# ---
#
# Use the code cell below to create an ecdf of `price`. The approximate what proportion of diamonds in the data have a price greater than or equal to 5000 USD.
#
# - The approximate proportion is 0.25.
#
# <br>
# <br>

# %%
# create an ecdf for price
plot(ecdf(diamonds$price),
     main = "ecdf(x)",
     col = "steelblue"
)
# Out:
# Plot with title “ecdf(x)”

# %% [markdown]
# ## <a name="hw2q2i">Question 2i</a>
#
# ---
#
#
# Using a logical test and either the `sum()` or `mean()` functions, calculate the exact proportion of diamonds in the `diamonds` data set that have a `price` that is greater than 5000 USD.
#
#
# ### Solution to Question 2i
#
# ---
#
# Use the code cell below to calculate the exact proportion. Type your final answer in the space below. Give your answer as a proportion rounded to four decimal places.
#
# - The exact proportion is 0.2730.
#
# <br>

# %%
# use a logical test to calculate exact proportion
mean(diamonds$price >= 5000)
# Out:
# [1] 0.2730256

# %% [markdown]
# ## <a name="hw2q2j">Question 2j</a>
#
# ---
#
#
# What proportion of `Ideal` diamonds have a price greater than 5000 USD?
#
# - Hint: You will first need to subset the data to create a data frame that contains only diamonds with a cut that is equal to `Ideal`.
# - Then use a logical test on the new data frame similar to [Question 2i](#hw2q2i).
#
# ### Solution to Question 2j
#
# ---
#
# Use the code cell below to calculate the exact proportion. Type your final answer in the space below. Give your answer as a proportion rounded to four decimal places.
#
# - The exact proportion is 0.2313.
#
# <br>

# %%
# subset the data in this code cell
idSub <- subset(diamonds, cut == "Ideal")

# %%
# use a logical test to calculate exact proportion
mean(idSub$price > 5000)
# Out:
# [1] 0.2313118

# %% [markdown]
# ## <a name="hw2q2k">Question 2k</a>
#
# ---
#
# What proportion of all diamonds in the data have a `cut` that is classified as `Ideal`?
#
# ### Solution to Question 2k
#
# ---
#
# Use the code cell below to calculate the exact proportion. Type your final answer in the space below. Give your answer as a proportion rounded to four decimal places.
#
# - The exact proportion is 0.3995.
#
# <br>

# %%
# use code cell to answer question 2k
mean(diamonds$cut == "Ideal")
# Out:
# [1] 0.3995365

# %% [markdown]
# ## <a name="hw2q2l">Question 2l</a>
#
# ---
#
# Create a contingency table (using `prop.table`) that is displayed on screen to determine **which type of `color` of diamond has the greatest proportion of observations with the best `clarity`**. Then enter your answer in the space below.
#
# - Note the `clarity` class `IF` is the best clarity.
#
# ### Solution to Question 2l
#
# ---
#
# Use the code cell below to create a contingency table to answer the question. Type your final answer in the space below. Give your answer as a proportion rounded to four decimal places.
#
# - The `color` of diamond has the greatest proportion of observations with the best `clarity` is G at 0.0603. This makes sense because the proportions are based on the total of the row(color) and not the total from all colors as that would favor the color with the most total IF instead of best proportional IF relative to the color total.
#
# <br>

# %%
# use code cell to create and display contingency table
prop.table(table(diamonds$color, diamonds$clarity), 1)
# Out:
#
#              I1         SI2         SI1         VS2         VS1        VVS2
#   D 0.006199262 0.202214022 0.307453875 0.250479705 0.104059041 0.081623616
#   E 0.010411350 0.174849444 0.247626825 0.252117995 0.130754313 0.101153414
#   F 0.014986376 0.168622930 0.223328443 0.230664431 0.142946971 0.102179837
#   G 0.013283741 0.137088204 0.174991144 0.207846263 0.190223167 0.127789586
#   H 0.019508671 0.188222543 0.273964355 0.197856455 0.140775530 0.073217726
#   I 0.016967909 0.168203615 0.262633714 0.215603098 0.177425304 0.067318333
#   J 0.017806268 0.170584046 0.267094017 0.260327635 0.193019943 0.046652422
#
#            VVS1          IF
#   D 0.037195572 0.010774908
#   E 0.066959273 0.016127386
#   F 0.076923077 0.040347935
#   G 0.088469713 0.060308183
#   H 0.070447977 0.036006744
#   I 0.065473995 0.026374032
#   J 0.026353276 0.018162393
