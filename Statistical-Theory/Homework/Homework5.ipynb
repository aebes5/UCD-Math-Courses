# %% [markdown]
# # Homework 5: Due Wednesday, February 21 at 11:00AM
#
# ---

# %% [markdown]
# ## <a name="HW1Inst">Instructions:</a>
# ---
#
# 1. <font color="tomato">Either click the COPY TO DRIVE button or use the menu File/Save/Save a Copy to save your own version of the notebook in your own folder in Google Drive.</font>
#
#   - If you do not have a Google account, you will need to create a Google account in order to create your own individual copy of this notebook.
#   - By default, the notebook will be saved in a folder named **Colab Notebooks** in your drive.
#   - Feel free to name and store the notebook wherever you like!
# v
# 2. <font color="mediumseagreen">After you have copied the notebook into your Drive, you can begin editing and saving your work.</font>
#
# **Upload your completed assignment into Canvas as a Google Colab (or Jupyter) Notebook with file extension `.ipynb`.**
#
# Upload your file into the Homework 5 assignment in Canvas before <font color="dodgerblue">**11AM on Wednesday, February 21.**</font>
#
# **You must provide supporting work for your all of your answers.**
#
#   - <font color="dodgerblue">That work will include using R code cells.</font>
#     - **Feel free to insert as much R code as you like.**
#     - You must interpret or explain how the output of a code cell is being utilized to solve the problem.
#     - **Code with incomplete or missing explanations of why the output is useful may not receive full credit.**
#   - <font color="dodgerblue">Your work will also involve writing explanations and justifications in text cells.</font>
#     - **Be sure to type/write out the steps of your work/explanation so I can see how you arrived at your answer.**
#   - <font color="mediumseagreen">Your work in [Question 1](#HW5q1) and [Question 3](#HW5q3) may involve doing algebra and/or calculus or you may use R. If you decide to use calculus methods:</font>
#     - **You can type supporting math equations and notation with LaTeX in text cells.**
#     - The LaTeX used in the Colab notebooks we cover in class provides great examples.
#     - Here's a helpful [Quick Reference Guide for LaTeX](https://colab.research.google.com/drive/1voDDmLfHmRWzWQW5yiHfqYsjGPFqdovP?usp=sharing).
#     - Here's a helpful [LaTeX math symbol gallery](https://artofproblemsolving.com/wiki/index.php/LaTeX:Symbols).
#     - **Learning LaTeX is super useful and might even be enjoyable!**
#   - <font color="tomato">If you decide to use calculus methods in either [Question 1](#HW5q1) or [Question 3](#HW5q3), and you prefer to not type answers with LaTeX, you can write your solutions on paper instead.</font>
#
#
# ## Important Academic Policies:
# ---
#
# - **Be your own work.** Though you may collaborate with others, everyone is responsible for writing up the work in their own way using their own methods. Plagiarism of any form is not tolerated.
# - **Be complete.** You must provide all work and/or explanations needed to find the solution. Answers with insufficient or incomplete supporting work may lose credit.
# - **Adhere to the Code of Academic Honesty.**
# - **Be clearly written (and legible if written).** Your solution to a problem must be clear, written in complete sentences. You may lose credit for work that is unclear or hard to follow.
#
# ## <font color="dodgerblue">Let me know if you need help, and **GOOD LUCK!!!**</font>
#
# ----

# %% [markdown]
# # <a name="HW5q1">Question 1</a>
#
# ---
#
# Suppose the reaction temperature $X$ (in ${}^{\circ}$C) in a chemical process has a uniform distribution with minimum value $-6^{\circ}\mbox{C}$ and maximum value $10^{\circ}\mbox{C}$.
#
# <br>

# %%
###Click here to view the PDF of my work from Q1
if (!requireNamespace("IRdisplay", quietly = TRUE)) {
  install.packages("IRdisplay")
}

library(IRdisplay)

pdf_url <- 'https://drive.google.com/file/d/1q1OcVj7fv_ToupnqE79yriYC4jRsdOb-/view?usp=sharing'

display_html(paste0('<a href="', pdf_url, '" target="_blank">Click here to view/download the PDF</a>'))
# Out:
# <a href="https://drive.google.com/file/d/1q1OcVj7fv_ToupnqE79yriYC4jRsdOb-/view?usp=sharing" target="_blank">Click here to view/download the PDF</a>

# %% [markdown]
# ## <a name="HW5q1a">Question 1a</a>
#
# ---
#
# What is the formula for the probability density function of $X$?
#
# <br>
#
# ### Solution to Question 1a
#
# ---
#
# **Replace the ?? in the LaTeX code below with an appropriate expression or value.** (No need to provide supporting work.)
#
# <br>
#
# $$f(x) = \left\{ \begin{array}{ll}
# 1/16 & -6 \leq x \leq 10 \\
# 0 & \mbox{otherwise}
# \end{array} \right. $$
#
# <br>

# %% [markdown]
# ## <a name="HW5q1b">Question 1b</a>
#
# ---
#
# Compute $P(2 < X < 5)$.
#
# <br>
#
# ### Solution to Question 1b
#
# ---
#
# Be sure to provide an explanation and/or supporting work to justify how you found your answer.
#
# 3/16
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW5q1c">Question 1c</a>
#
# ---
#
# Find the values for $E(X)$ and $\mbox{Var}(X)$.
#
# <br>
#
# *Note: You are welcome to apply "shortcut" formulas from the common distribution formula sheet.*
#
# <br>
#
# ### Solution to Question 1c
#
# ---
#
# Be sure to provide an explanation and/or supporting work to justify how you found your answer.
#
# E(X) = 2
#
# Var(X) = 21.333
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW5q1d">Question 1d</a>
#
# ---
#
# Using your answer from [Question 1a](#HW5q1a) and the general fact that the cdf $F(x)$ is an antiderivative of the pdf $f(x)$, derive the formula for the cumulative distribution function $F(x)$ using calculus.
#
# <br>
#
#
# ### Solution to Question 1d
#
# ---
#
# Be sure to provide an explanation and/or supporting work to justify how you found your answer.
#
# <br>
# <br>
#
# **Replace the ?? in the LaTeX code below with an appropriate expression or value to express your final answer.**
#
# <br>
#
# $$F(x) = \left\{ \begin{array}{ll}
# 0 & x < -6 \\
# x/16 & -6 \leq x \leq 10 \\
# 1 & x > 10
# \end{array} \right. $$
#
# <br>

# %% [markdown]
# # <a name="HW5q2">Question 2</a>
#
# ---
#
# The mean systolic blood pressure for all adults 18 and over is normally distributed with a mean of $122$ millimeters of mercury (mm Hg)<sup>1</sup>. Let random variable $X$ be the systolic blood pressure for a randomly selected adult 18 or older.
#
#
#
# <br>
#
# <font size=2>1. [National Health Statistics Report](https://www.cdc.gov/nchs/data/nhsr/nhsr035.pdf) Number 35, by Wright, et al. Center for Disease Control, March 25, 2011.</font>

# %% [markdown]
# ## <a name="HW5q2a"> Question 2a</a>
#
# ---
#
# Suppose we know that 2.5% of adults 18 or older have systolic blood pressure less than $82$ mm HG. Give an approximation for the standard deviation, denoted $\sigma_X$, for the distribution of systolic blood pressure of all adults 18 years or older.
#
# - You will need to use the value of $\sigma_X$ you find in this part to answer the rest of the parts of this question.
# - If you get an incorrect value of $\sigma_X$ but answer the remaining parts correctly based on that value, you will not lose any additional points.
# - <font color="mediumseagreen">Hint: Recall the Empirical Rule for normal distribtions!</font>
#
# <br>
#
# ### Solution to Question 2a
#
# ---
#
# Be sure to provide supporting work or explanation to justify how you determined your answer.
#
#
# 20
#
# <br>
# <br>
# <br>

# %%
# optional code cell for supporting work to question 2a
# using 68, 95, 99.7 rule

(122 - 82) / 2
# Out:
# [1] 20

# %% [markdown]
# ## <a name="HW5q2b">Question 2b</a>
#
# ---
#
# A person with systolic blood pressure over 180 mm HG is diagnosed with hypertensive crisis. Using your approximation from [Question 2a](#HW5q2a), what is the $z$-score for a person with systolic blood pressure equal to 180 mm HG ?
#
# ### Solution to Question 2b
#
# ---
#
# Be sure to provide an explanation and/or supporting work to justify how you found your answer, and then **interpret the practical meaning of your answer.** You may use the R code cell below for supporting work.
#
# z = 2.9
#
# <br>
# <br>
# <br>
#
# **Interpret the practical meaning of the value:**
#
# This individual's blood pressure is very high and they should probably make sure they get it checked out. They are 2.9 sd's above the mean, which means they are in the top ~1% of individuals 18 or older for their blood pressure.
#
#
# <br>
# <br>
# <br>

# %%
# optional code cell for supporting work to question 2b

(180 - 122) / 20
# Out:
# [1] 2.9

# %% [markdown]
# ## <a name="HW5q2c">Question 2c</a>
#
# ---
#
# If the $z$-score of a person's systolic blood pressure is $-1.8$, then what is their systolic blood pressure (in mm HG)?
#
# <br>
#
# ### Solution to Question 2c
#
# ---
#
# Be sure to provide an explanation and/or supporting work to justify how you found your answer. You may use the R code cell below for supporting work.
#
#
# 86
# <br>
# <br>
# <br>

# %%
# optional code cell for supporting work to question 2c

122 + (-1.8 * 20)
# Out:
# [1] 86

# %% [markdown]
# ## <a name="HW5q2d">Question 2d</a>
#
# ---
#
# If a person 18 or older is selected at random, what is the probability they have a systolic blood pressure that is at most 180 mm HG?
#
# <br>
#
# ### Solution to Question 2d
#
# ---
#
# Be sure to provide an explanation and/or supporting work (which may be R code entered in the code cell below) to justify how you found your answer.
#
# 0.998
# <br>
# <br>
# <br>

# %%
# code cell for supporting work to question 2d

pnorm(180, 122, 20)
# Out:
# [1] 0.9981342

# %% [markdown]
# ## <a name="HW5q2d">Question 2d</a>
#
# ---
#
# What is the probability that a random selected person 18 or older has a systolic blood pressure between 110 and 140 mm HG?
#
# <br>
#
# ### Solution to Question 2d
#
# ---
#
# Be sure to provide an explanation and/or supporting work (which may be R code entered in the code cell below) to justify how you found your answer.
#
# 0.542
# <br>
# <br>
# <br>

# %%
# code cell for supporting work to question 2d
pnorm(140, 122, 20) - pnorm(110, 122, 20)
# Out:
# [1] 0.5416868

# %% [markdown]
# ## <a name="HW5q2e">Question 2e</a>
#
# ---
#
# What is the 99th percentile for systolic blood pressure for an adult 18 or older?
#
# <br>
#
# ### Solution to Question 2e
#
# ---
#
# Use the code cell below to find and display your answer.
#
# 168.527
#
# <br>
# <br>

# %%
# code cell for supporting work to question 2e

qnorm(0.99, 122, 20)
# Out:
# [1] 168.527

# %% [markdown]
# # <a name="HW5q3">Question 3</a>
#
# ---
#
#
# Video streaming services record users' requests to stream videos to optimize the use of the available bandwidth. Let $X$ be the amount of time that passes between successive requests by users of a video streaming service. Based on data from an experiement<sup>2</sup>, the distribution of times between successive requests to stream a video is exponentially distributed with an average time of $1.2$ seconds per streaming request. Use this model for the distribution $X$, time between streaming requests, to answer the questions that follow.
#
# <br>
#
# <font size=2>2. "[Distributed Client-Assisted Patching for Multicast Video-on-Demand Service in an Enterprise Network](https://ieeexplore.ieee.org/document/4313272)", S. M. Farhad and M. M. Akbar. *Journal of Computers*, 2017.</font>

# %% [markdown]
# ## <a name="HW5q3a">Question 3a</a>
#
# ---
#
#
# What is the probability that the time between streaming requests is at most 2 seconds? Set up an integral to represent this probability. Then using R commands or calculus, compute this probability.
#
# <br>
#
# ### Solution to Question 3a
#
# ---
#
# Set up an integral to represent this probability. Complete the LaTeX code below to express your answer.
#
# - Note: To enter $e^{-kx}$ in LaTeX type `e^{-kx}`.
#
#
# $$\int_0^2 5/6e^{-5/6x} \, dx.$$
#
#
# Compute the probability either by using the R code cell below or showing how you evaluated the integral above. You can choose whether to use R or calculus, but either way be sure to provide supporting work.
#
#
# 0.811
#
# <br>
# <br>
# <br>

# %%
# optional code cell for supporting work to question 3a

pexp(2, 5/6)
# Out:
# [1] 0.8111244

# %% [markdown]
# ## <a name="HW5q3b">Question 3b</a>
#
# ---
#
# What is the probability that the time between streaming requests is at least 1 second? Set up an integral to represent this probability. Then using R commands or calculus, compute this probability.
#
# <br>
#
# ### Solution to Question 3b
#
# ---
#
# Set up an integral to represent this probability. Complete the LaTeX code below to express your answer.
#
# - Note: To enter $e^{-kx}$ in LaTeX type `e^{-kx}`.
#
# $$1 - \int_0^1 5/6e^{5/6x} \, dx.$$
#
#
# Compute the probability either by using the R code cell below or showing how you evaluated the integral above. You can choose whether to use R or calculus, but either way be sure to provide supporting work.
#
#
# 0.435
#
# <br>
# <br>
# <br>

# %%
# optional code cell for supporting work to question 3b
1 - pexp(1, (5/6))
# Out:
# [1] 0.4345982

# %% [markdown]
# ## <a name="HW5q3c">Question 3c</a>
#
# ---
#
# What is the probability that the time between streaming requests is between 1 and 2 seconds?
#
#
# <br>
#
# ### Solution to Question 3c
#
# ---
#
# Be sure to provide an explanation and/or supporting work (which may involve some calculus, R code, and/or results from previous questions) to justify how you found your answer.
#
# 0.246
#
# <br>
# <br>
# <br>

# %%
# optional code cell for supporting work to question 3c

pexp(2, (5/6)) - pexp(1, (5/6))
# Out:
# [1] 0.2457226

# %% [markdown]
# ## <a name="HW5q3d">Question 3d</a>
#
# ---
#
# Find the values of $E(X)$ and $\mbox{Var}(X)$.
#
# <br>
#
#
# ### Solution to Question 3d
#
# ---
#
# Be sure to provide an explanation and/or supporting work to justify how you found your answer. You are encouraged to apply "shortcut" formulas from the formula sheet for common distributions when justifying your answers as long as you show/explain how you used those formulas to find your answers.
#
# E(X) = 1.2
#
# Var(X) = 1.44
#
# <br>
# <br>
# <br>

# %%
# optional code cell for supporting work to question 3d
1 / (5/6)
1 / ((5/6) ** 2)
# Out:
# [1] 1.2
# [1] 1.44

# %% [markdown]
# ## <a name="HW5q3e">Question 3e</a>
#
# ---
#
# Suppose we randomly select a sample of $n=10$ different times between streaming requests. If possible, use the Central Limit Theorem (CLT) to compute the probability that the mean time between streaming requests of the sample is less than 2 seconds?
#
# <br>
#
# If the Central Limit Theorem cannot be applied, then instead of computing this probability explain why the CLT cannot be applied.
#
# <br>
#
# ### Solution to Question 3e
#
# ---
#
#
# Either explain why CLT cannot be applied, or use the R code cell below to compute the probability.
#
# While each event is independent, indicating the CLT could be used, n = 10 times is too small of a sample to use the CLT: the general informal amount being ~ n >= 30.
#
# <br>
# <br>
# <br>

# %%
# use code cell to compute probability if CLT applies

# if CLT cannot be applied, explain in space above and
# do not use this code cell to compute anything

# %% [markdown]
# ## <a name="HW5q3f">Question 3f</a>
#
# ---
#
# Suppose we randomly select a sample of $n=40$ different times between streaming requests. If possible, use the Central Limit Theorem (CLT) to compute the probability that the mean time between streaming requests of the sample is less than 2 seconds?
#
# <br>
#
# If the Central Limit Theorem cannot be applied, then instead of computing this probability explain why the CLT cannot be applied.
#
# <br>
#
# ### Solution to Question 3f
#
# ---
#
#
# Either explain why CLT cannot be applied, or use the R code cell below to compute the probability.
#
# It rounds to 1.
#
# <br>
# <br>
# <br>

# %%
# use code cell to compute probability if CLT applies

# if CLT cannot be applied, explain in space above and
# do not use this code cell to compute anything

pnorm(2, 1.2, 1.2/sqrt(40))
# Out:
# [1] 0.9999876
# [1] 0.9999876

# %% [markdown]
# # <a name="HW5q">Question 4</a>
#
# ---
#
# Let $X$ be the birth weight, in grams, of a randomly selected full-term baby.
# An article<sup>1</sup> suggests that $X$ is normally distributed with mean 3500 grams and standard deviation 600 grams.
#
# <br>
#
# <font size="2">1. "Fetal Growth Parameters and Birth Weight: Their Relationship to Neonatal Body Composition'" (Ultrasound in Obstetrics and Gynecology, 2009: 441--446)</font>
#
# <br>

# %% [markdown]
# ## <a name="HW5q4a">Question 4a</a>
#
# ---
#
# What is $P(2700 < X < 4000)$?
#
# <br>
#
# ### Solution to Question 4a
#
# ---
#
# Be sure to provide an explanation and/or supporting work (which may be R code entered in the code cell below) to justify how you found your answer.
#
#
# 0.706
# <br>
# <br>
# <br>

# %%
# code cell for supporting work to question 4a

pnorm(4000, 3500, 600) - pnorm(2700, 3500, 600)
# Out:
# [1] 0.7064604

# %% [markdown]
# ## <a name="HW5q4b">Question 4b</a>
#
# ---
#
# What is the probability that the weight of such a newborn is more than 4500 g (rougly 10 lb)?
#
#
# <br>
#
# ### Solution to Question 4b
#
# ---
#
# Be sure to provide an explanation and/or supporting work (which may be R code entered in the code cell below) to justify how you found your answer.
#
# 0.048
# <br>
# <br>
# <br>

# %%
# code cell for supporting work to question 4b

1 - pnorm(4500, 3500, 600)
# Out:
# [1] 0.04779035

# %% [markdown]
# ## <a name="HW5q4c">Question 4c</a>
#
# ---
#
# What is the probability that the weight of such a newborn is less than 2700 g (roughly 6 lb)?
#
# <br>
#
# ### Solution to Question 4c
#
# ---
#
# Be sure to provide an explanation and/or supporting work (which may be R code entered in the code cell below) to justify how you found your answer.
#
#
# 0.091
#
# <br>
# <br>
# <br>

# %%
# code cell for supporting work to question 4c

pnorm(2700, 3500, 600)
# Out:
# [1] 0.09121122

# %% [markdown]
# ## <a name="HW5q4d">Question 4d</a>
#
# ---
#
# Suppose $15$ infants are randomly selected. If possible, use the Central Limit Theorem (CLT) to compute the probability that the mean birth weight of the sample is less than 3500 grams?
#
# <br>
#
# If the Central Limit Theorem cannot be applied, then instead of computing this probability explain why the CLT cannot be applied.
#
# <br>
#
# ### Solution to Question 4d
#
# ---
#
#
# Either explain why CLT cannot be applied, or use the R code cell below to compute the probability.
#
#
# The CLT cannot be applied because the sample size of 15 infants is too small.
# <br>
# <br>
# <br>

# %%
# use code cell to compute probability if CLT applies

# if CLT cannot be applied, explain in space above and
# do not use this code cell to compute anything

# %% [markdown]
# ## <a name="HW5q4e">Question 4e</a>
#
# ---
#
# Suppose $40$ infants are randomly selected. If possible, use the Central Limit Theorem (CLT) to compute the probability that the mean birth weight of the sample is less than 3500 grams?
#
# <br>
#
# If the Central Limit Theorem cannot be applied, then instead of computing this probability explain why the CLT cannot be applied.
#
# <br>
#
# ### Solution to Question 4e
#
# ---
#
#
# Either explain why CLT cannot be applied, or use the R code cell below to compute the probability.
#
#
# It is 0.5.
# <br>
# <br>
# <br>

# %%
# use code cell to compute probability if CLT applies

# if CLT cannot be applied, explain in space above and
# do not use this code cell to compute anything

pnorm(3500, 3500, 600/sqrt(40))
# Out:
# [1] 0.5

# %% [markdown]
# ## <a name="HW5q4f">Question 4f</a>
#
# ---
#
# Suppose $100$ infants are randomly selected. If possible, use the Central Limit Theorem (CLT) to compute the probability that the mean birth weight of the sample is greater than 4000 grams?
#
# <br>
#
# If the Central Limit Theorem cannot be applied, then instead of computing this probability explain why the CLT cannot be applied.
#
# <br>
#
# ### Solution to Question 4f
#
# ---
#
#
# Either explain why CLT cannot be applied, or use the R code cell below to compute the probability.
#
# It is 0.
#
# <br>
# <br>
# <br>

# %%
# use code cell to compute probability if CLT applies

# if CLT cannot be applied, explain in space above and
# do not use this code cell to compute anything

1 - pnorm(4000, 3500, 600/sqrt(100))
# Out:
# [1] 0
