# %% [markdown]
# # Homework 1: Due Wednesday, January 24 at 11:00AM
#
# ---

# %%
factorial(30)/(factorial(15))
# Out:
# [1] 2.028432e+20

# %%
factorial(30) / (factorial(15) ** 2)
# Out:
# [1] 155117520

# %% [markdown]
# ## <a name="HW1Inst">Instructions:</a>
# ---
#
# 1. <font color="tomato">Either click the COPY TO DRIVE button or use the menu File/Save/Save a Copy to save your own version of the notebook in your own folder in Google Drive.</font>
#
#   - If you do not have a Google account, you will need to create a Google account in order to create your own individual copy of this notebook.
#   - By default, the notebook will be saved in a folder named **Colab Notebooks** in your drive.
#   - Feel free to name and store the notebook wherever you like!
#
# 2. <font color="mediumseagreen">After you have copied the notebook into your Drive, you can begin editing and saving your work.</font>
#
# **Upload your completed assignment into Canvas as a Google Colab (or Jupyter) Notebook with file extension `.ipynb`.**
#
# Upload your file into the Homework 1 assignment in Canvas before <font color="dodgerblue">**11AM on Wednesday, January 24.**</font>
#
# **You must provide supporting work for your all of your answers.**
#
#   - <font color="dodgerblue">That work will include using R code cells.</font>
#     - **Feel free to insert as much R code as you like.**
#     - You must interpret or explain how the output of a code cell is being utilized to solve the problem.
#     - **Code with incomplete or missing explanations of why the output is useful may not receive full credit.**
#   - <font color="dodgerblue">Your work will also involve writing explanations and justifications in text cells.</font>
#     - **Be sure to type/write out the steps of your work/explanation so I can see how you arrived at your answer.**
#
#
# ## Important Academic Policies:
# ---
#
# - **Be your own work.** Though you may collaborate with others, everyone is responsible for writing up the work in their own way using their own methods. Plagiarism of any form is not tolerated.
# - **Be complete.** You must provide all work and/or explanations needed to find the solution. Answers with insufficient or incomplete supporting work may lose credit.
# - **Adhere to the Code of Academic Honesty.**
# - **Be clearly written (and legible if written).** Your solution to a problem must be clear, written in complete sentences. You may lose credit for work that is unclear or hard to follow.
#
# ## <font color="dodgerblue">Let me know if you need help, and **GOOD LUCK!!!**</font>
#
# ----

# %% [markdown]
# # <a name="google">Question 0</a>
#
# ---
#
# Your assignment will be graded in Google Colaboratory (we will score and add comments to your work). Your marked up work will be returned in a shared Google Drive folder (not in Canvas). Thus, we need to know the email that is attached to your Google account in order to return your work.
#
#
# - If you do not have a Google account, you will need to create a Google account in order to save your own work.
#
#
# <mark>In the space below, please enter the email that is attached to your Google account?<mark>
#
# <br>
#
# <font color="dodgerblue">**Email for Google:**</font> lionclaw005@gmail.com

# %% [markdown]
# # <a name="HW1Q1">Question 1</a>
#
# ---
#
#
# The Food and Drug Administration (FDA) recently approved a new drug to treat early stage dementia. The quote below is from a *New York Times* article<sup>1</sup> summarizing the results of the study. If you would like to read the full New York Times article either go to the [NYTimes website linked here](https://www.nytimes.com/2023/01/06/health/alzheimers-drug-leqembi-lecanemab.html) (that may be behind a pay wall) or [click here to download a pdf version of the full New York Times article](https://drive.google.com/uc?export=download&id=14ob9WwiAjeSoSDspuVVNnxen_ecURS-U) (not behind a pay wall).
#
# <br>
#
# <font size ="2">1. "F.D.A Approves New Treatment for Early Alzheimer's" by Pam Belluck, *New York times* published on January 6, 2023.</font>
#
# > The Food and Drug Administration on Friday approved a new Alzheimer's drug that may modestly slow the pace of cognitive decline early in the disease, but also carries risks of swelling and bleeding in the brain.
#
# > The approval of the drug, lecanemab, to be marketed as Leqembi, is likely to generate considerable interest from patients and physicians. Studies of the drug --- an intravenous infusion administered every two weeks --- suggest it is more promising than the scant number of other treatments available. Still, several Alzheimer's experts said it was unclear from the medical evidence whether Leqembi could slow cognitive decline enough to be noticeable to patients.
#
# The New York Times article refers to a New England Journal of Medicine report of findings on an 18 month study on Leqembi. The report is a summary co-written by scientists from lead company making Leqembi.
#
# ### <a name="back">BACKGROUND</a>
#
# The accumulation of soluble and insoluble aggregated amyloid-beta (A$\beta$) may initiate or potentiate pathologic processes in Alzheimer's disease. Lecanemab, a humanized IgG1 monoclonal antibody that binds with high affinity to A$\beta$ soluble protofibrils, is being tested in persons with early Alzheimer's disease.
#
# ### <a name="methods">METHODS</a>
#
# We conducted an 18-month, multicenter, double-blind, phase 3 trial involving persons 50 to 90 years of age with early Alzheimer's disease (mild cognitive impairment or mild dementia due to Alzheimer's disease) with evidence of amyloid on positron-emission tomography (PET) or by cerebrospinal fluid testing. Participants were randomly assigned in a 1:1 ratio to receive intravenous lecanemab (10 mg per kilogram of body weight every 2 weeks) or placebo.
#
# The primary end point was the change from baseline at 18 months in the score on the
#
# -   Clinical Dementia Rating--Sum of Boxes (CDR-SB; range, 0 to 18, with higher scores indicating greater impairment).
#
# Key secondary end points in a substudy were:
#
# -   the change in amyloid burden on PET,
# -   the score on the 14-item cognitive subscale of the Alzheimer's Disease Assessment Scale (ADAS-cog14; range, 0 to 90; higher scores indicate greater impairment),
# -   the Alzheimer's Disease Composite Score (ADCOMS; range, 0 to 1.97; higher scores indicate greater impairment), and
# -   the score on the Alzheimer's Disease Cooperative Study--Activities of Daily Living Scale for Mild Cognitive Impairment (ADCS-MCI-ADL; range, 0 to 53; lower scores indicate greater impairment).
#
# ### <a name="results">RESULTS</a>
#
# A total of 1795 participants were enrolled, with 898 assigned to receive lecanemab and 897 to receive placebo. The mean CDR-SB score at baseline was approximately 3.2 in both groups. The adjusted least-squares mean change from baseline at 18 months was 1.21 with lecanemab and 1.66 with placebo (difference, $-0.45$; 95% confidence interval [CI], $-0.67$ to $-0.23$; $P < 0.001$).
#
# In a substudy involving 698 participants, there were greater reductions in brain amyloid burden with lecanemab than with placebo (difference, $-59.1$ centiloids; 95% CI, $-62.6$ to $-55.6$). Other mean differences between the two groups in the change from baseline favoring lecanemab were as follows: for the ADAS-cog14 score, $-1.44$ (95% CI, $-2.27$ to $-0.61$; $P < 0.001$); for the ADCOMS, $-0.050$ (95% CI, $-0.074$ to $-0.027$; $P < 0.001$); and for the ADCS-MCI-ADL score, $2.0$ (95% CI, $1.2$ to $2.8$; $P < 0.001$). Lecanemab resulted in infusion-related reactions in 26.4% of the participants and amyloid-related imaging abnormalities with edema or effusions in 12.6%.
#
# ### <a name="conclude">CONCLUSIONS</a>
#
# Lecanemab reduced markers of amyloid in early Alzheimer's disease and resulted in moderately less decline on measures of cognition and function than placebo at 18 months but was associated with adverse events. Longer trials are warranted to determine the efficacy and safety of lecanemab in early Alzheimer's disease. (Funded by Eisai and Biogen; Clarity AD ClinicalTrials.gov number, [NCT03887455](http://clinicaltrials.gov/show/NCT03887455).)

# %% [markdown]
# ## <a name="HW1Q1a">Question 1a</a>
#
# ---
#
# Was this an observational study or an experiment? What information in the report lead to your conclusion? Support your answer with a brief explanation (one or two sentences).
#
# <br>
#
# ### Solution to Question 1a
#
# ---
#
# This is an experiment because there are participants who were randomly assigned to groups; additionally, variables are manipulated: drug vs placebo.
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW1Q1b">Question 1b</a>
#
# ---
#
# How many individuals are in the **treatment group** in the full study? How many individuals are in the **control group** in the full study? Do you believe the two groups (treatment and control) will differ in ways besides whether or not they receive lecanemab? Support your answer with a brief explanation (one or two sentences).
#
# <br>
#
# ### Solution to Question 1b
#
# ---
# There were 898 individuals in the treatment group and 897 individuals in the control group. The groups shouldn't differ because the individuals were selected into the groups randomly and not based on some external factor.
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW1Q1c">Question 1c</a>
#
# ---
#
# Based on the [RESULTS](#results) summarized above, do you believe lecanemab is associated with slowing the progression of early stage Alzheimer's as measured by **response variable change in score on the Clinical Dementia Rating--Sum of Boxes (CDR-SB)** test (ignoring the substudy on secondary end points).
#
# *Base your answer purely on the values stated in the [RESULTS](#results) section and not on the design of study or other relevant factors that you will consider next.* Support your answer with a brief explanation (one or two sentences), and in particular which value(s) influenced your answer.
#
#
# <br>
#
# ### Solution to Question 1c
# ---
# In this case, lecanemab couldn't be credited for slowing the progression because going strictly off of the values 0.45 would indicate it did help, however, not using relevant factors would discredit the integrity of the experiment as an external factor could be the reason and not the drug.
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW1Q1d">Question 1d</a>
#
# ---
#
# Do you believe their are any confounding variables? Recall a confounding variable is another variable (besides the treatment and response variables) that may be associated with both the treatment and response variables. Support your answer with a brief explanation (one or two sentences).
#
# ### Solution to Question 1d
#
# ---
# A possible confounding variable in this case would be the fact that the individuals volunteered to be part of the experiment; however, there wouldn't really be a way to conduct this experiment without people volunteering. Additionally, the age range could be a confounding variable, but given the fact that individuals are randomly assigned this shouldn't change the conclusion.
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW1Q1e">Question 1e</a>
#
# ---
#
# Based on the report above, do you support the FDA's decision to approve the use of lecanemab to treat early stage Alzheimer's disease? Support your answer with an clear explanation (two sentences or more) taking into account whatever factors you think are relevant to this decision.
#
#
# ### Solution to Question 1e
#
# ---
# Yes I do support the decision because the experiment seems quite credible, especially with using random assignment to groups which could be the main confounding variable in this situation. Additionally, the number of participants seem to be enough, giving the results validity considering the results in the study and substudy unanimously indicate lecanemab is effective.
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# # <a name="HW1Q2">Question 2</a>
#
# ---
#
# This question refers to an article titled "Association of sleep duration in middle and old age with incidence of dementia"<sup>2</sup> about a study designed to analyze sleep patterns in middle and old age and future incidence of dementia.
#
#
#
# There were 7,959 participants whose sleep duration was measured at ages 45-55 and tracked over the full course of the 34 year study. These participants were placed into one of **three different treatment groups** based on their observed sleeping patterns:
#
# -   The *Short Sleep (SS)* group consists of 3149 participants that were observed to sleep on average less than 6 hours of sleep per night.
# -   The *Normal Sleep (NS)* group consists of 3624 participants that were observed to sleep on average 7 hours of sleep per night.
# -   The *Long Sleep (LS)* group consists of 1186 participants that were observed to sleep on average more than 8 hours of sleep per night.
#
# The response is whether on not the participant developed dementia over the course of the 34 year study. The results are summarized in the two-way table below.
#
# |                    | SS   | NS   | LS   | Total |
# |--------------------|------|------|------|-------|
# | Developed Dementia | 211  | 219  | 91   | 521   |
# | Did not            | 2938 | 3405 | 1095 | 7438  |
# | Total              | 3149 | 3624 | 1186 | 7959  |
#
#
# <br>  <br>
#
# <font size="2">2. Sabia, S., Fayosse, A., Dumurgier, J. et al. Association of sleep duration in middle and old age with incidence of dementia. *Nature Communications* 12, 2289 (2021). <https://doi.org/10.1038/s41467-021-22354-2></a>

# %% [markdown]
# ## <a name="HW1Q2a">Question 2a</a>
#
# ---
#
# Based on the data in the two-way table above, which group (SS, NS, LS) seems to has the greatest risk of dementia? Which group (SS, NS, LS) seems to has the lowest risk of dementia? Show or explain how you determined your answers.
#
# <br>
#
# ### Solution to Question 2a</a>
#
# ---
# The LS group was most likely to get dementia because they had 7.67% of participants develop dementia while NS was 6.04% and SS was 6.70%. For the same reason, NS has the lowest risk of dementia.
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW1Q2b">Question 2b</a>
#
# ---
#
# The article ([read the summary here](https://www.nature.com/articles/s41467-021-22354-2)) identifies some possible confounding variables involved in the study. After reading the article, identify at least two different confounding variables. *Hint: Pay particular attention to the RESULTS section of the article*.
#
# <br>
#
# ### Solution to Question 2b</a>
#
# ---
# A couple confounding variables could be the participants who died prior to following up and distinguishing sex despite that not being what was originally distinguished - rather sleep and dementia.
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW1Q2c">Question 2c</a>
#
# ---
#
# This study is an observational study. Explain how you could instead design a randomized experiment to determine whether there is a connection between sleep patterns at age 45-55 and risk of developing dementia. For now, you should ignore any moral, ethical, or other practical considerations. You will comment on these other, very important considerations next.
#
# <br>
#
# ### Solution to Question 2c
#
# ---
# You could monitor random peoples' house between the age of 45-55, analyze their sleep, and further track if they develop dementia over 25 years. Randomly monitor people instead of people volunteering because a case like that might have people more/less prone to dementia based on a common attribute.
# <br>
# <br>
# <br>

# %% [markdown]
# # <a name="HW1Q2d">Question 2d</a>
#
# ---
#
# What are some moral, ethical, or other practical considerations with your experimental design in [Question 2c](#HW1Q2c)?
#
#
# <br>
#
# ### Solution to Question 2d
#
# ---
# You can't randomly monitor somebody sleeping without their recognition and consent.
# <br>
# <br>
# <br>

# %% [markdown]
# # <a name="HW1Q3">Question 3</a>
#
# ---
#
# In the code cell below, a dataframe called `insurance` that can be analyzed for insurance forecasting based on various features. The original data set was downloaded in comma-separated values (.csv) format from Kaggle<sup>3</sup>.
#
# <br>
#
# <font size="2">3. Choi, Miri. Medical Cost Personal Datasets. Retrieved January 12, 2023 from <https://www.kaggle.com/datasets/mirichoi0218/insurance>.</font>

# %%
#####################################################
# There is NOTHING TO EDIT in this code
# Run this code cell to import data as data frame
#####################################################
insurance <- read.csv(file = "https://raw.githubusercontent.com/CU-Denver-MathStats-OER/Statistical-Theory/main/Data/insurance.csv",
                  header = TRUE,
                  sep = ",",)

# Some Data Wrangling to Help Clean the Data
insurance$sex <- factor(insurance$sex)
insurance$smoker <- factor(insurance$smoker)
insurance$region <- factor(insurance$region)

# %% [markdown]
# ## Data Dictionary
#
# Interesting features include BMI, Number of Children, and if the person is a smoker or not.
#
# -   `age`: age of primary beneficiary
# -   `sex`: gender of primary beneficiary assigned at birth
# -   `bmi`: Body mass index of primary beneficiary
# -   `children`: Number of children covered by health insurance of primary beneficiary
# -   `smoker`: Does primary beneficiary smoke cigarettes.
# -   `region`: the beneficiary's residential area in the US.
# -   `charges`: Medical costs billed by health insurance to the primary beneficiary

# %% [markdown]
# ## <a name="HW1Q3a">Question 3a</a>
#
# ---
#
# How many health insurance policies are included in the data set?
# <br>
#
# ### Solution to Question 3a
#
# ---
# 0 policies are included in the data set unless I am misinterpretting the meaning.
# <br>
# <br>
# <br>

# %%
# Here is an R code cell if needed
# to help answer Question 3a

summary(insurance)
# Out:
#       age            sex           bmi           children     smoker
#  Min.   :18.00   female:662   Min.   :15.96   Min.   :0.000   no :1064
#  1st Qu.:27.00   male  :676   1st Qu.:26.30   1st Qu.:0.000   yes: 274
#  Median :39.00                Median :30.40   Median :1.000
#  Mean   :39.21                Mean   :30.66   Mean   :1.095
#  3rd Qu.:51.00                3rd Qu.:34.69   3rd Qu.:2.000
#  Max.   :64.00                Max.   :53.13   Max.   :5.000
#        region       charges
#  northeast:324   Min.   : 1122
#  northwest:325   1st Qu.: 4740
#  southeast:364   Median : 9382
#  southwest:325   Mean   :13270
#                  3rd Qu.:16640
#                  Max.   :63770

# %% [markdown]
# ## <a name="HW1Q3b">Question 3b</a>
#
# ---
#
# List all of the categorical variables in the data set.
#
# <br>
#
# Be sure to provide supporting explanation or R code to show how you determined your answer. You may refer to output from the prior code cell to answer this question and may not need to use an additional code cell.
#
# <br>
#
# ### Solution to Question 3b
#
# ---
# The categorical variables are sex, smoker, and region.
#
# <br>
# <br>
# <br>

# %%
# Here is an R code cell if needed
# to provide supporting work for 3b
View(insurance)
# Out:
#      age sex    bmi    children smoker region    charges
# 1    19  female 27.900 0        yes    southwest 16884.924
# 2    18  male   33.770 1        no     southeast  1725.552
# 3    28  male   33.000 3        no     southeast  4449.462
# 4    33  male   22.705 0        no     northwest 21984.471
# 5    32  male   28.880 0        no     northwest  3866.855
# 6    31  female 25.740 0        no     southeast  3756.622
# 7    46  female 33.440 1        no     southeast  8240.590
# 8    37  female 27.740 3        no     northwest  7281.506
# 9    37  male   29.830 2        no     northeast  6406.411
# 10   60  female 25.840 0        no     northwest 28923.137
# 11   25  male   26.220 0        no     northeast  2721.321
# 12   62  female 26.290 0        yes    southeast 27808.725
# 13   23  male   34.400 0        no     southwest  1826.843
# 14   56  female 39.820 0        no     southeast 11090.718
# 15   27  male   42.130 0        yes    southeast 39611.758
# ...

# %% [markdown]
# ## <a name="HW1Q3c">Question 3c</a>
#
# ---
#
# List all of the quantitative variables in the data set.
#
# <br>
#
# Be sure to provide supporting explanation or R code to show how you determined your answer. You may refer to output from prior code cells to answer this question and may not need to use an additional code cell.
#
# <br>
#
# ### Solution to Question 3c
#
# ---
# The quantitative variables are age, bmi, children, and charges.
#
#
# <br>
# <br>
# <br>

# %%
# Here is an R code cell if needed
# to provide supporting work for 3c

View(insurance)
# Out:
#      age sex    bmi    children smoker region    charges
# 1    19  female 27.900 0        yes    southwest 16884.924
# 2    18  male   33.770 1        no     southeast  1725.552
# 3    28  male   33.000 3        no     southeast  4449.462
# 4    33  male   22.705 0        no     northwest 21984.471
# 5    32  male   28.880 0        no     northwest  3866.855
# 6    31  female 25.740 0        no     southeast  3756.622
# 7    46  female 33.440 1        no     southeast  8240.590
# 8    37  female 27.740 3        no     northwest  7281.506
# 9    37  male   29.830 2        no     northeast  6406.411
# 10   60  female 25.840 0        no     northwest 28923.137
# 11   25  male   26.220 0        no     northeast  2721.321
# 12   62  female 26.290 0        yes    southeast 27808.725
# 13   23  male   34.400 0        no     southwest  1826.843
# 14   56  female 39.820 0        no     southeast 11090.718
# 15   27  male   42.130 0        yes    southeast 39611.758
# ...

# %% [markdown]
# # You are Done with Homework 1!!!
