# %% [markdown]
# # Homework 3: Due Wednesday, February 7 at 11:00AM
#
# ---

# %% [markdown]
# ## <a name="HW1Inst">Instructions:</a>
# ---
#
# **Upload your completed assignment into Canvas as a Google Colab (or Jupyter) Notebook with file extension `.ipynb`.**
#
# Upload your file into the Homework 3 assignment in Canvas before <font color="dodgerblue">**11AM on Wednesday, February 7.**</font>
#
# **You must provide supporting work for your all of your answers.**
#
#
#
#   - <font color="dodgerblue">That work will include using R code cells.</font>
#     - **Feel free to insert as much R code as you like.**
#     - You must interpret or explain how the output of a code cell is being utilized to solve the problem.
#     - **Code with incomplete or missing explanations of why the output is useful may not receive full credit.**
#   - <font color="dodgerblue">Your work will also involve writing explanations and justifications in text cells.</font>
#     - **Be sure to type/write out the steps of your work/explanation so I can see how you arrived at your answer.**
#   - <font color="mediumseagreen">Your work in [Question 4](#HW3Q4) and [Question 5](#HW3Q5) will involve doing algebra and/or calculus.</font>
#     - **You can type supporting math equations and notation with LaTeX in text cells.**
#     - The LaTeX used in the Colab notebooks we cover in class provides great examples.
#     - Check out the [LaTeX-Quick-Reference Guide](https://colab.research.google.com/drive/1voDDmLfHmRWzWQW5yiHfqYsjGPFqdovP?usp=sharing).
#     - Here's a helpful [LaTeX cheat sheet](https://www.cmor-faculty.rice.edu/~heinken/latex/symbols.pdf).
#     - **Learning LaTeX is super useful and might even be enjoyable, but it is NOT required.**
#   - <font color="tomato">In [Question 4](#HW3Q4) and [Question 5](#HW3Q5), if you prefer to not type answers with LaTeX, you can write your solutions instead.</font>
#     - I get it, you are busy and doing it by hand might be more efficient? Maybe not? You get to decide!
#     - If you submit written work, be sure you provide clear and complete solutions.
#     - **I'm happy to get well written solutions in any form!**
#
#
# ## Important Academic Policies:
#
# ---
#
# - **Be your own work.** Though you may collaborate with others, everyone is responsible for writing up the work in their own way using their own methods. Plagiarism of any form is not tolerated.
# - **Be complete.** You must provide all work and/or explanations needed to find the solution. Answers with insufficient or incomplete supporting work may lose credit.
# - **Adhere to the Code of Academic Honesty.**
# - **Be clearly written (and legible if written).** Your solution to a problem must be clear, written in complete sentences. You may lose credit for work that is unclear or hard to follow.
#
# ## <font color="dodgerblue">Let me know if you need help, and **GOOD LUCK!!!**</font>
#
# ----

# %% [markdown]
# # <a name="HW3Q1">Question 1</a>
#
# ---
#
# Home mortgages can be classified as fixed rate $F$ or variable rate $V$. A sample of four home mortgages are selected and the type of mortgage of each is recorded.
#
# <br>
#
# <font color="dodgerblue">When answering the questions below, the ordering is important. For example, outcomes $FFFV$ and $FVFF$ are considered two different outcomes because their ordering is different.</font>

# %% [markdown]
# ## <a name="HW3Q1a">Question 1a</a>
#
# ---
#
# How many outcomes are in the sample space? Show and/or explain how you determined your answer.
#
# ### Solution to Question 1a
#
# ---
#
# The sample space $\Omega$ has a total of 16 outcomes.
#
# <br>
#
# *Provide supporting work or explanation below.*
# 2^5 = 16
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW3Q1b">Question 1b</a>
#
# ---
#
# List all outcomes (using notation such as $FFFV$) in the event "at least three of the selected mortgages are fixed rate".
#
# ### Solution to Question 1b
#
# ---
# 5 outcomes: FFFV
# FFVF
# FVFF
# VFFF
# FFFF
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW3Q1c">Question 1c</a>
#
# ---
#
# List all outcomes in the event "exactly three mortgages are of the same type".
#
# ### Solution to Question 1c
#
# ---
# 8 outcomes: FFFV
# FFVF
# FVFF
# VFFF
# VVVF
# VVFV
# VFVV
# FVVV
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW3Q1d">Question 1d</a>
#
# ---
#
# List all outcomes in the event "the sample has less fixed rate mortgages than variable rate".
#
# ### Solution to Question 1d
#
# ---
# 5 outcomes: VVVV
# VVVF
# VVFV
# VFVV
# FVVV
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW3Q1f">Question 1e</a>
#
# ---
#
# What is the union of the events in parts [Question 1c](#HW3Q1c) and [Question 1d](#HW3Q1d)?
#
# What is the intersection of these two events?
#
# <br>
#
#
# ### Solution to Question 1e
#
# ---
#
# <br>
#
# The union consists of the outcomes: FFFV
# FFVF
# FVFF
# VFFF
# VVVF
# VVFV
# VFVV
# FVVV
# VVVV
#
# <br>
#
# The intersection consists of the outcomes: VVVF VVFV VFVV FVVV
#
# <br>
# <br>

# %% [markdown]
# ## <a name="HW3Q1f">Question 1f</a>
#
# ---
#
# Assuming 55% of all mortgages are fixed rate and 45% are variable rate and each mortgage selected is independent of the others that are selected, what is the probability that at least three of the selected mortgages are fixed rate?
#
#
#
# ### Solution to Question 1f
#
# ---
# (0.55^4) + 4(0.55^3 * 0.45) = 0.3910
# <br>
#
# Provide supporting work or explanation to justify your answer.
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# # <a name="HW3Q2">Question 2</a>
#
# ---
#
# The R package `MASS` contains a data set `Pima.te` that is a data set collected by the [US National Institute of Diabetes and Digestive and Kidney Diseases](https://www.niddk.nih.gov/) with health records from 532 [Pima Indian](https://www.gilariver.org/index.php/about/culture) (Aikmel O'otham) women living near Phoenix, Arizona that were age 21 or above. In the questions below, we will consider whether there is an association between Body Mass Index (BMI) and diabetes incidence.
#
#
# - [Body Mass Index (BMI)](https://www.nhlbi.nih.gov/health/educational/lose_wt/BMI/bmicalc.htm) is a measure of body fat based on height and weight.
#   - Each person's BMI is stored in `bmi` as a quantitative variable.
#   - According to the World Health Organization, a person with a BMI score of 30 or above is considered obese.
#
# - Each person in the data was tested for diabetes based on the [World Health Organization (WHO) criteria](https://www.who.int/news-room/fact-sheets/detail/diabetes).
#   - The categorical variable `type` contains two classes, `Yes` and `No`, depending on whether the individual is diabetic (according to WHO criteria).
#
#
# <font color="dodgerblue">Run the code cell below to load the `MASS` library and get an initial summary of all variables in the `Pima.te` data set.</font>

# %%
library(MASS)
summary(Pima.te)
# Out:
#      npreg             glu              bp              skin
#  Min.   : 0.000   Min.   : 65.0   Min.   : 24.00   Min.   : 7.00
#  1st Qu.: 1.000   1st Qu.: 96.0   1st Qu.: 64.00   1st Qu.:22.00
#  Median : 2.000   Median :112.0   Median : 72.00   Median :29.00
#  Mean   : 3.485   Mean   :119.3   Mean   : 71.65   Mean   :29.16
#  3rd Qu.: 5.000   3rd Qu.:136.2   3rd Qu.: 80.00   3rd Qu.:36.00
#  Max.   :17.000   Max.   :197.0   Max.   :110.00   Max.   :63.00
#       bmi             ped              age         type
#  Min.   :19.40   Min.   :0.0850   Min.   :21.00   No :223
#  1st Qu.:28.18   1st Qu.:0.2660   1st Qu.:23.00   Yes:109
#  Median :32.90   Median :0.4400   Median :27.00
#  Mean   :33.24   Mean   :0.5284   Mean   :31.32
#  3rd Qu.:37.20   3rd Qu.:0.6793   3rd Qu.:37.00
#  Max.   :67.10   Max.   :2.4200   Max.   :81.00

# %% [markdown]
# ## <a name="HW3Q2a">Question 2a</a>
#
# ---
#
#
# If we use the classification that a person with a BMI score greater than or equal to 30 is obese, then what proportion of the people in the `Pima.te` data would be considered obese?
#
# Use a logical test and a `sum()` command in the code cell below to find the exact number of people that would be classified as obese.
#
# ### Solution to Question 2a
#
# ---
#
# Use the code cell below to answer.
#
# <br>

# %%
# How many people in the data are
# classified as obese? 214
# Hint: Use a logical test and a sum() command
sum(Pima.te$bmi >= 30)
# Out:
# [1] 214

# %% [markdown]
# ## <a name="HW3Q2a">Question 2b</a>
#
# ---
#
# The code cell below performs some data wrangling.
#
# 1. We create a new categorical variable named `weight`.
#   - If `bmi` is greater than or equal to 30, `weight` is equal to `obese`.
#   - If `bmi` is less than 30, `weight` is equal to `not`.
#   - We convert `weight` to a categorical factor.
#
# 2. We subset the `Pima.te` data by extracting just the `weight` and `type` variables. The new data frame is stored as `pima`.
#
# 3. A summary of the cleaned data frame `pima` is displayed to the screen.
#
#
# Run the code cell below to perform the three operations indicated above (there is nothing to edit in the code). Based on the output from the  `summary` command, answer the following questions below.
#
# <br>
#
#
#
# ### Solution to Question 2b
#
# ---
#
#
# - How many total people are included in the data set `pima`?
#
#  - Enter answer here.
# 332
# <br>
#
# - How many people were diagnosed as diabetic?
#
#  - Enter answer here. 109
#
# <br>
#
#
# - How many people were diagnosed as obese?
#
#  - Enter answer here. 214
#
#
# <br>
# <br>

# %%
Pima.te$weight[Pima.te$bmi >= 30]  <- "obese"  # obese if bmi >= 30
Pima.te$weight[Pima.te$bmi < 30]  <- "not"  # not obese if bmi < 30
Pima.te$weight <- factor(Pima.te$weight)  # convert weight to factor

# extract and store only weight and type to pima
pima <- subset(Pima.te, select = c(weight, type))

summary(pima)  # numerical summary of counts
nrow(pima)
# Out:
#    weight     type
#  not  :118   No :223
#  obese:214   Yes:109
# [1] 332

# %% [markdown]
# ## <a name="HW3Q2c">Question 2c</a>
#
# ---
#
# Consider the following notation:
#
# - Let $D$ denote the event a randomly selected Pima women in the sample is diagnosed as diabetic.
#
# - Let $D'$ denote the event a randomly selected Pima women in the sample is NOT diagnosed as diabetic.
#
# - Let $O$ denote the event a randomly selected Pima women in the sample is diagnosed as obese.
# - Let $O'$ denote the event a randomly selected Pima women in the sample is NOT diagnosed as obese.
#
# If we randomly select a Pima women from the sample contained in `pima`, calculate and interpret the practical meaning of:
#
# (i) $P(D)$
#
# (ii) $P(O)$
#
# (iii) $P(D \cup O)$
#
# (iv) $P(D \cap O)$
#
#
# <br>
#
# ### Solution to Question 2c
#
# ---
#
#
# You will need to use either or both the `table` and/or `prop.table` function(s) in R along with the data set `pima` created in [Question 2b](#HW3Q2b) to answer this question. **Provide supporting code for your answers in the code cell below.**
#
# <br>
#
# Type your answers in the space below, rounding proportions to four decimal places if needed. **For each proportion, be sure you write a one sentence interpretation of the practical meaning of the value.**
#
# <br>
#
# (i) $P(D) = 0.3283$
#
# Interpretation (i):
# The likelihood that a randomly selected Pima women in the sample is diagnosed as diabetic.
#
# <br>
# <br>
#
# (ii) $P(O) = 0.6446$
#
# Interpretation (ii):
# The likelihood that a randomly selected Pima women in the sample is obese.
#
# <br>
# <br>
#
#
# (iii) $P(D \cup O) = 0.7018$
#
# Interpretation (iii):
# The likelihood that a randomly selected Pima women in the sample is obese or diabetic(or both).
#
#
# <br>
# <br>
#
#
# (iv) $P(D \cap O) = 0.2711$
#
# Interpretation (iv):
# The likelihood that a randomly selected Pima women in the sample is obese and is diabetic.
#
#
# <br>
# <br>
# <br>

# %%
# code to support answers above
sum(pima$type == "Yes") / 332
sum(pima$weight == "obese") / 332
sum(pima$type == "Yes" | pima$weight == "obese") / 332
sum(pima$type == "Yes" & pima$weight == "obese") / 332
# Out:
# [1] 0.3283133
# [1] 0.6445783
# [1] 0.7018072
# [1] 0.2710843

# %% [markdown]
# # <a name="HW3Q2d">Question 2d</a>
#
# ---
#
# Given a Pima woman from the sample is diagnosed with diabetes, what is the probability that they are obese?
#
#
# ### Solution to Question 2d
#
# ---
#
# <br>
#
# You will need to use either or both the `table` and/or `prop.table` function(s) in R  along with the data set `pima` created in [Question 2b](#HW3Q2b) to answer this question.
#
# - **Provide supporting code for your answer in the code cell below.**
# - Express your answer using probability notation by completing the equation provided below.
#
# <br>
#
# $$P( O | D ) = 0.8257 $$
#
#
# <br>
# <br>

# %%
# code to support answer above
sum(pima$type == "Yes" & pima$weight == "obese") / sum(pima$type == "Yes")
# Out:
# [1] 0.8256881

# %% [markdown]
# ## <a name="HW3Q2e">Question 2e</a>
#
# ---
#
# Given a Pima woman from the sample is obese, what is the probability they are diagnosed with diabetes?
#
#
# ### Solution to Question 2e
#
# ---
#
# <br>
#
# You will need to use either or both the `table` and/or `prop.table` function(s) in R  along with the data set `pima` created in [Question 2b](#HW3Q2b) to answer this question.
#
# - **Provide supporting code for your answer in the code cell below.**
# - Express your answer using probability notation by completing the equation provided below.
#
#
# $$P( D | O ) = 0.4206 $$
#
#
# <br>
# <br>

# %%
# code to support answer above
sum(pima$type == "Yes" & pima$weight == "obese") / sum(pima$weight == "obese")
# Out:
# [1] 0.4205607

# %% [markdown]
# ## <a name="HW3Q2f">Question 2f</a>
#
# ---
#
# What is one additional, relevant conditional probability we can compare with the probability from [Question 2e](#HW3Q2e) to help determine whether there is an increased risk in a diabetes if a Pima women over 21 is obese?
#
# <br>
#
# ### Solution to Question 2f
#
# ---
#
# <br>
#
#
# State the value of a relevant conditional probability to compare with [Question 2e](#HW3Q2e) using the probability notation provided below.
#
# $$P( D | O' ) = 0.1610 $$
#
#
# <br>
# <br>
#
# Based on the comparison of the probability you stated above and the probability you computed in [Question 2e](#HW3Q2e), do you believe this study supports the claim that obesity increases the risk of developing diabetes? **Explain how you determined your answer.**
#
# The study does support the claim that obesity increases the risk of developing diabetes because the probablity an obese person has diabetes is 0.4206 while the probability a non-obese person has diabetes is only 0.1610. There seems to be a causation between obesity and having diabetes from the data.
#
# <br>
# <br>
# <br>

# %%
# if needed use additional code to support answer above
sum(pima$type == "Yes" & pima$weight == "not") / sum(pima$weight == "not")
# Out:
# [1] 0.1610169

# %% [markdown]
# ## <a name="HW3Q2g">Question 2g</a>
#
# ---
#
# Create one stacked bar chart to clearly display the conditional probabilities you compared in [Question 2f](#HW3Q2f). Be sure you use the data set `pima` created in [Question 2b](#HW3Q2b).
#
# <br>
#
# ### Solution to Question 2g
#
# ---
#
# Use the code cell below to create your plot. No explanation needed.
#
# <br>
# <br>

# %%
# use code cell to create a stacked bar chart
barplot(table(pima$type, pima$weight),
        main = "Correlation between Obesity and Diabetes", xlab = "Obesity", ylab = "Frequency",
legend = TRUE)
# Out:
# Plot with title “Correlation between Obesity and Diabetes”

# %% [markdown]
# # <a name="HW3Q3">Question 3</a>
#
# ---
#
# Most medical screening tests are not perfectly accurate. The accuracy is typically measured using two conditional probabilities:
#
# -   The <font color="tomato">sensitivity</font> of the test is the probability that a person with the disease correctly receives a positive test. This is a <font color="tomato">Correct Positive</font>.
#
# $$\color{tomato}{\mbox{Sensitivity} = P\left( + \mbox{ Test } \big| \mbox{ Has Disease} \right)}$$
#
# -   The <font color="dodgerblue">specificity</font> of the test is the probability that a person without the disease correctly receives a negative test. This is a <font color="dodgerblue">Correct Negative</font>.
#
# $$\color{dodgerblue}{\mbox{Specificity} = P( - \mbox{ Test } \big| \mbox{ No Disease})}$$
#
# This problem will focus on the Mini Mental State Examination (MMSE), which is the most commonly used test for complaints of problems with memory or other mental abilities<sup>1</sup>.
#
# -   <font color="tomato">The sensitivity of the MMSE is 80%, $P\left( + \mbox{ Test } \big| \mbox{ Has Disease} \right) = 0.8$</font>.
# -   <font color="dodgerblue">The specificity of the MMSE is 90%, $P\left( - \mbox{ Test } \big| \mbox{ No Disease} \right) = 0.9$</font>.
#
# **Approximately 11% of Americans over the age of 65 suffer from Alzheimer's dementia<sup>2</sup>.**
#
# <br>
#
# <font size="2">1. Alzheimer's Society: [Tests and scans used to diagnose dementia](https://www.alzheimers.org.uk/about-dementia/symptoms-and-diagnosis/diagnosis/mmse-test).</font>
#
# <font size="2">2. Alzheimer's Association: [Alzheimer's Disease Facts and Figures](https://www.alz.org/alzheimers-dementia/facts-figures).</font>
#
# <br>
#
# ---
#
# <br>
#
#
# The table below is suggested as a hint to help. You do not need to use to use it, but it might be helpful to fill in the blanks before answering the questions below. For example, if 1000 Americans over the age of 65 are randomly screened by the MMSE for Alzheimer's dementia, then we have:
#
# <br>
#
#
# |        | Has Alzheimer's | Does Not Have Alzheimer's | Total |
# |--------|-----------------|-------------|-------|
# | Test+ | 88  | 89  | 177    |
# | Test - | 22  | 801   | 823  |
# | Total  | 110  | 890  | 1,000 |

# %% [markdown]
# ## <a name="HW3Q3">Question 3a</a>
#
# ---
#
# What is the probability that a randomly tested adult over the age of 65 will test positive?
#
#
# ## Solution to Question 3a
#
# ---
# 177 / 1000 = 0.1770
#
# <br>
#
# Provide supporting work along with your answer.
#
#
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW3Q3b">Question 3b</a>
#
# ---
#
# Given that a patient tests positive for Alzheimer's, what is the probability they actually have Alzheimer's?
#
#
# ### Solution to Question 3b
#
# ---
# 88 / 177 = 0.4972
#
# <br>
#
# Provide supporting work along with your answer.
#
#
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# # <a name="HW3Q4">Question 4</a>
#
# ---
#
# The current in a certain circuit as measured by an ammeter is a continuous random variable $X$ with the following probability distribution function:
#
# $$f(x) = \left\{ \begin{array}{ll} 0.075x + 0.2  \ \ \ \ & 3 \leq x \leq 5\\
#   0 & \text{otherwise} \end{array} \right. .$$
#
# Run the code cell below to sketch a graph of the pdf.

# %%
# Define the breakpoints
x <- c(0, 3, 5, 7)

# Define the function values for each segment
y1 <- c(0, 0, NA, NA)
y2 <- c(NA, 0.425, 0.575, NA)
y3 <- c(NA, NA, 0, 0)

# Create a scatter plot of the points for the first segment
plot(x, y1,
     type = "o",
     xlim = c(0,7),
     ylim = c(0, 0.6),
     lty = 1,
     col = "blue",
     xlab = "x",
     ylab = "f(x)",
     main = "Graph of Probability Density Function, f(x)")
lines(x, y2, type = "l", lty = 1, col = "red")
lines(x, y3, type = "o", lty = 1, col = "blue")
# Out:
# Plot with title “Graph of Probability Density Function, f(x)”

# %% [markdown]
# ## <a name="HW3Q4a">Question 4a</a>
#
# ---
#
# Calculate $P(X \leq 4)$ and explain how you could represent this proportion in the graph of the pdf above.
#
# <br>
#
# ### Solution to Question 4a
#
# ---
#
#
# Be sure to provide all supporting work for how you calculated $P(X \leq 4)$.
#
#
#
# <br>
# <br>
# <br>
#
# Explain how you could represent the proportion in the graph of the pdf above.
#
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW3Q4b">Question 4b</a>
#
# ---
#
# Find a formula for the cumulative distribution function (cdf), $F(x)$.
# Be sure to provide supporting work.
#
# ### Solution to Question 4b
#
# ---
#
# Be sure to provide all supporting work.
#
#
# <br>
# <br>
#
# Then enter your final answer as a piecewise function by completing the LaTeX code below.
#
#
# $$F(x) = \left\{ \begin{array}{ll}
# 0 & x \leq ?? \\
# ?? & ?? < x < ?? \\
# 1 & x \geq ??
#  \end{array} \right. .$$
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW3Q4c">Question 4c</a>
#
# ---
#
# On a separate piece of paper that should not submitted, sketch a graph of the cdf $F(x)$ you found in [Question 4b](#HW3Q4b).
#
# <font color="tomato">**This is for your practice, not collected.**</font>
#
# <br>
#
# ### Solution to Question 4c
#
# ---
#
# Sketch a graph on a separate piece of paper that will not be collected submitted.

# %% [markdown]
# ## <a name="HW3Q4d">Question 4d</a>
#
# ---
#
# Calculate the median value of $X$.
# Be sure to provide supporting work.
#
# -   For practice (not collected) mark this value on the graph of the cdf you sketched in [Question 4c](#HW3Q4c).
#
# <br>
#
# ### Solution to Question 4d
#
# ---
#
# Be sure to provide all supporting work.
#
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW3Q4e">Question 4e</a>
#
# ---
#
# Calculate the 75th percentile of $X$.
# Be sure to provide supporting work.
#
# -   For practice (not collected) mark this value on the graph of the cdf you sketched in [Question 4c](#HW3Q4c).
#
# <br>
#
# ### Solution to Question 4e
#
# ---
#
# Be sure to provide all supporting work.
#
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# # <a name="HW3Q5">Question 5</a>
#
# ---
#
# Let $X$ denote the amount of time (in hours) that a car remains parked after paying a parking meter for a maximum of 2 hours.
# For example $x=0.5$ means a car was parked for a half-hour and then left.
# $x=2$ means a car uses the spot for the full 2 hours.
# The cumulative distribution function (cdf) for $X$ is:
#
# $$F(x) = \left\{
#   \begin{array}{ll}
#    0  \ \ & x \leq 0 \\
#    \frac{x^2}{9} & 0 < x < 3 \\
#    1 & x \geq 3
#   \end{array} \right. .$$

# %% [markdown]
# ## <a name="HW3Q5a">Question 5a</a>
#
# ---
#
# Compute $P(X < 1)$. Show your supporting work below.
#
# <br>
#
# ### Solution to Question 5a
#
# ---
#
# Be sure to provide all supporting work.
#
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW3Q5b">Question 5b</a>
#
# ---
#
# Compute $P(1 \leq X \leq 2)$.
# Show your supporting work below.
#
# <br>
#
# ### Solution to Question 5b
#
# ---
#
# Be sure to provide all supporting work.
#
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW3Q5c">Question 5c</a>
#
# ---
#
# Compute $P(X > 2.5)$.
# Show your supporting work below.
#
# <br>
#
# ### Solution to Question 5c
#
# ---
#
# Be sure to provide all supporting work.
#
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW3Q5d">Question 5d</a>
#
# ---
#
# Give a formula for $f(x)$, the probability distribution function (pdf) of $X$.
# Show your supporting work below.
#
# <br>
#
# ### Solution to Question 5d
#
# ---
#
# Be sure to provide all supporting work.
#
#
#
# <br>
# <br>
#
# Then enter your final answer as a piecewise function by completing the LaTeX code below.
#
#
# $$f(x) = \left\{ \begin{array}{ll}
# ?? &  ?? \leq x \leq ?? \\
# 0 & \text{ otherwise}
#  \end{array} \right. .$$
#
# <br>
# <br>
# <br>
