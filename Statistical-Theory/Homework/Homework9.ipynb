# %% [markdown]
# # Homework 9: Due Wednesday, April 10 at 11:00AM
#
# ---

# %% [markdown]
# ## <a name="HW1Inst">Instructions:</a>
# ---
#
# 1. <font color="tomato">Either click the COPY TO DRIVE button or use the menu File/Save/Save a Copy to save your own version of the notebook in your own folder in Google Drive.</font>
#
#   - If you do not have a Google account, you will need to create a Google account in order to create your own individual copy of this notebook.
#   - By default, the notebook will be saved in a folder named **Colab Notebooks** in your drive.
#   - Feel free to name and store the notebook wherever you like!
# v
# 2. <font color="mediumseagreen">After you have copied the notebook into your Drive, you can begin editing and saving your work.</font>
#
# **Upload your completed assignment into Canvas as a Google Colab (or Jupyter) Notebook with file extension `.ipynb`.**
#
# Upload your file into the Homework 9 assignment in Canvas before <font color="dodgerblue">**11AM on Wednesday, April 10.**</font>
#
# **You must provide supporting work for your all of your answers.**
#
#   - <font color="dodgerblue">That work will include using R code cells.</font>
#     - **Feel free to insert as much R code as you like.**
#     - You must interpret or explain how the output of a code cell is being utilized to solve the problem.
#     - **Code with incomplete or missing explanations of why the output is useful may not receive full credit.**
#   - <font color="dodgerblue">Your work will also involve writing explanations and justifications in text cells.</font>
#     - **Be sure to type/write out the steps of your work/explanation so I can see how you arrived at your answer.**
#   - <font color="dodgerblue">Your work in some parts may involve doing algebra and/or calculus.</font>
#     - **You can type supporting math equations and notation with LaTeX in text cells.**
#     - The LaTeX used in the Colab notebooks we cover in class provides great examples.
#     - Here's a helpful [Quick Reference Guide for LaTeX](https://colab.research.google.com/drive/1voDDmLfHmRWzWQW5yiHfqYsjGPFqdovP?usp=sharing).
#     - Here's a helpful [LaTeX math symbol gallery](https://artofproblemsolving.com/wiki/index.php/LaTeX:Symbols).
#     - **Learning LaTeX is super useful and might even be enjoyable!**
#
#
# ## Important Academic Policies:
# ---
#
# - **Be your own work.** Though you may collaborate with others, everyone is responsible for writing up the work in their own way using their own methods. Plagiarism of any form is not tolerated.
# - **Be complete.** You must provide all work and/or explanations needed to find the solution. Answers with insufficient or incomplete supporting work may lose credit.
# - **Adhere to the Code of Academic Honesty.**
# - **Be clearly written (and legible if written).** Your solution to a problem must be clear, written in complete sentences. You may lose credit for work that is unclear or hard to follow.
#
# ## <font color="dodgerblue">Let me know if you need help, and **GOOD LUCK!!!**</font>
#
# ----

# %% [markdown]
# # <a name="HW9q1">Question 1</a>
#
# ------------------------------------------------------------------------
#
# Suppose a student is working on a project using data on daily screen time from a random sample of 100 students at her university. She finds a 95% confidence interval for the daily screen time to be from 6.5 hours to 8.2 hours. Explain (in complete sentences) why each of the statements below would be an improper interpretation of this interval.

# %% [markdown]
# ## <a name="HW9q1a">Question 1a</a>
#
# ------------------------------------------------------------------------
#
# I am 95% confident that the interval from 6.5 hours to 8.2 hours will contain the mean daily screen time of a random sample of 100 students selected at this university.
#
# ### Solution to Question 1a
#
# ------------------------------------------------------------------------
#
# Explain (in complete sentences) why the statement is an **improper interpretation** of this interval.
#
# There's 95% confidence that the interval contains the population mean not hte sample mean - so students at the university as a whole not the 100 students selected.
#
#
#
#
#
# <br>
# <br>

# %% [markdown]
# ## <a name="HW9q1b">Question 1b</a>
#
# ------------------------------------------------------------------------
#
# 95% of the students in the sample of 100 students selected have a daily screen time between 6.5 hours and 8.2 hours.
#
# ### Solution to Question 1b
#
# ------------------------------------------------------------------------
#
# Explain (in complete sentences) why the statement is an **improper interpretation** of this interval.
#
#
#
#
#
# <br>
# <br>

# %% [markdown]
# ## <a name="HW9q1c">Question 1c</a>
#
# ------------------------------------------------------------------------
#
# There is a 95% chance that the interval from 6.5 hours to 8.2 hours will contain the daily screen time for a randomly selected student at this university.
#
# ### Solution to Question 1c
#
# ------------------------------------------------------------------------
#
# Explain (in complete sentences) why the statement is an **improper interpretation** of this interval.
#
#
# The 95% chance is the interval containing the population mean not a randomly selected student.
#
#
# <br>
# <br>

# %% [markdown]
# ## <a name="HW9q1d">Question 1d</a>
#
# ------------------------------------------------------------------------
#
# There is a 95% chance the mean screen time for all students at this university is between 6.5 hours and 8.2 hours.
#
# ### Solution to Question 1d
#
# ------------------------------------------------------------------------
#
# Explain (in complete sentences) why the statement is an **improper interpretation** of this interval.
#
# The order should be flipped; so the 95% chance isn't assigned to the mean but rather the interval. So, there's a 95% chance the interval contains the mean screen time for all students at the university.
#
#
# <br>
# <br>

# %% [markdown]
# # <a name="HW9q2">Question 2</a>
#
# ------------------------------------------------------------------------
#
# The Medical College Admission Test (MCAT) is a standardized test designed to assess problem-solving, critical thinking, and knowledge of natural, behavioral, and social science concepts. The MCAT is prerequisite for applying to medical schools in the United States.
#
# - In 2022, the average MCAT score of all people who took the MCAT was $\mu=500$ with a standard deviation of $\sigma=10.8$.
#
# From a random sample of 50 students at your university, you find the average MCAT score of the sample is 510. However, you forgot to compute the standard deviation of your sample, so you assume the standard deviation of MCAT scores at your university is the same as the standard deviation of the population, $\sigma = 10.8$.

# %% [markdown]
# ## <a name="HW9q2a">Question 2a</a>
#
# ------------------------------------------------------------------------
#
# Compute a 95% confidence interval for $\mu$, the mean MCAT score for all students who took the MCAT exam at this university.
#
# -   Show your work by replacing each of the <mark>??</mark> below with an appropriate value.
#
# ### Solution to Question 2a
#
# ------------------------------------------------------------------------
#
# i.  An initial point estimate is $\mu \approx $<mark>510</mark>.
#
# ii. The value of $z_{\alpha/2}$ for a 95% confidence level is <mark>1.96</mark>.
#
# -   Round your answer to two decimal places when typing it above.

# %%
# Show work by entering a formula (using qnorm)
z<-qnorm(0.975, 0, 1)
z
# Out:
# [1] 1.959964

# %% [markdown]
# iii. The standard error of the underlying sampling distribution is $\mbox{SE}(\bar{X}) =$ <mark>1.53</mark>.
#
# -   Round your answer to two decimal places when typing it above.

# %%
# Show work by entering a calculation
# that gives the standard error
se<- 10.8 / sqrt(50)
se
# Out:
# [1] 1.527351

# %% [markdown]
# iv. The margin of error (MoE) for a 95% confidence interval is <mark>2.99</mark>.
#
# -   Round your answer to two decimal places when typing it above.

# %%
# Show work by entering a calculation
# that gives the margin of error.
moe<- z * se
moe

510 - moe
510 + moe
# Out:
# [1] 2.993552
# [1] 507.0064
# [1] 512.9936

# %% [markdown]
# v.  A 95% confidence interval for the mean MCAT score for all students who took the MCAT exam at this university is from <mark>507.0</mark> to <mark>513.0</mark>.
#
# -   Round your answers to one decimal place when typing them above.

# %% [markdown]
# ## <a name="HW9q2b">Question 2b</a>
#
# ------------------------------------------------------------------------
#
# Interpret the meaning of the confidence interval you found in [Question 2a](#HW9q2a) in practical terms to a person who does not come from a statistics background.
#
# -   Be sure to keep in the mind the cautions we discussed in class regarding interpretations of confidence intervals.
#
# Based on your interpretation, answer the question below. Explain how you determined your answer.
#
#
#
# > Do you believe based on the data this school performs better than average?
#
#
# ### Solution to Question 2b
#
# ------------------------------------------------------------------------
#
# **Write your interpretation below:**
#
# There's a 95% chance the interval 507.0 to 513.0 contains the population mean of all students at the university who took the MCAT.
#
# <br>
# <br>
#
# Do you believe based on the data this school performs better than average? Explain.
#
#
# It seems likely this school performs better than average given the interpretation above, while the mean MCAT score for all university students was 500. It is worth noting, however, that the standard deviation provided was for students at all universities and not the specific university of our sample; this would result in less accurate estimates and would depend on how much the sample standard deviation varies from the population standard deviation.
#
#
# <br>
# <br>

# %% [markdown]
# # <a name="HW9q3">Question 3</a>
#
# ------------------------------------------------------------------------
#
# A researcher is interested in the sugar content of vanilla ice cream. They obtain random samples of $n=30$ brands (each sample is a half cup serving of ice cream) and finds an average of 19.55 grams of sugar with a standard deviation of 6 grams. Assuming the distribution of sugar content of all brands of vanilla ice cream is normally distributed, **find a 99% confidence interval for the mean amount of sugar in a half cup serving of vanilla ice cream.**
#
# -   Show your work by replacing each of the <mark>??</mark> below with an appropriate value.
#
# ### Solution to Question 3
#
# ------------------------------------------------------------------------
#
# i.  An initial point estimate is $\mu \approx $ <mark>19.55</mark>.
#
# ii. The value of $t_{\alpha/2}$ for a 99% confidence level is <mark>2.756</mark>.
#
# -   Round your answer to three decimal places when typing it above.

# %%
# Show work by entering a formula
tval<-qt(0.995, 29)
tval
# Out:
# [1] 2.756386

# %% [markdown]
# iii. The standard error of the underlying sampling distribution is $\mbox{SE}(\bar{X}) =$ <mark>1.095</mark>.
#
# -   Round your answer to three decimal places when typing it above.

# %%
# Show work by entering a calculation
# that gives the standard error
se<- 6 / sqrt(30)
se
# Out:
# [1] 1.095445

# %% [markdown]
# iv. The margin of error (MoE) for a 99% confidence interval is <mark>3.019</mark>.
#
# -   Round your answer to three decimal places when typing it above.

# %%
# Show work by entering a calculation
# that gives the margin of error.
moe<- se * tval
moe

19.55 - moe
19.55 + moe
# Out:
# [1] 3.019469
# [1] 16.53053
# [1] 22.56947

# %% [markdown]
# v.   A 99% confidence interval for the mean amount of sugar in a half cup serving of vanilla ice cream is from <mark>16.531</mark> grams to <mark>22.569</mark> grams.
#
# -   Round your answers to three decimal places when typing them above.

# %% [markdown]
# # <a name="q4">Question 4</a>
#
# ------------------------------------------------------------------------
#
# In 2022, the average flight time of all United Airlines (UA) nonstop flights from Denver to Philadelphia was 205 minutes and the population standard deviation was 25.3 minutes. You want to construct a 90% confidence interval for the mean length of time of UA nonstop flights from Denver to Philadelphia in 2023 based on a random sample of UA nonstop flights from Denver to Philadelphia in 2023. **What is the minimum size of the sample needed in order to have a margin of error of three minutes or less?**
#
# -   You may assume the standard deviation of the population of all UA nonstop flights from Denver to Philadelphia in 2023 is equal to the standard deviation of the all flight lengths in 2022.
#
#
# ## Solution to Question 4
#
# ------------------------------------------------------------------------
#
# Show supporting work/calculations in the space below.
# Answer without any supporting work will not earn credit.
#
# The sample must be greater than or equal to 193.
#
#
# <br>
# <br>

# %%
# Here's an R code cell if you'd like to use it!
(25.3 * qnorm(0.95,  0, 1) / 3) ** 2
# Out:
# [1] 192.4213

# %% [markdown]
# # <a name="HW9q5">Question 5</a>
#
# ------------------------------------------------------------------------
#
# The `PlantGrowth` data set in the `datasets` package contains the results from an experiment to compare yields (as measured by dried weight of plants, in grams) obtained under a control and two different treatments.
#
# **You will need to run the code cell below to load `datasets` before answering the questions that follow.**

# %%
library(datasets)  # load package

# %%
summary(PlantGrowth)  # summary of data
# Out:
#      weight       group
#  Min.   :3.590   ctrl:10
#  1st Qu.:4.550   trt1:10
#  Median :5.155   trt2:10
#  Mean   :5.073
#  3rd Qu.:5.530
#  Max.   :6.310

# %% [markdown]
# ## <a name="HW9q5a">Question 5a</a>
#
# ------------------------------------------------------------------------
#
# Create three side by side box plots in one single plot to compare the weights of the three different groups (control, treatment group 1, and treatment group 2)
#
# ### Solution to Question 5a
#
# ---
#
# Use the code cell below to create ONE SINGLE PLOT with all three boxplots.
#
# <br>
# <br>

# %%
# use code cell to create side-by-side boxplots
boxplot(weight ~ group,
        data = PlantGrowth,
        cex.lab=1.5, cex.axis=1.5, cex.main=1.5)
# Out:
# plot without title

# %% [markdown]
# ## <a name="HW9q5b">Question 5b</a>
#
# ----
#
# Based on the plot from [Question 5a](#HW9q5a), which treatment do you believe is most effective at producing the greatest yield? Support your answer with an brief explanation based on the plot you created.
#
# ### Solution to Question 5b
#
# ---
#
# trt2 is the most effective at producing the greatest yield because it has the greatest value for all of the quartiles.
#
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## <a name="HW9q5c">Question 5c</a>
#
# ------------------------------------------------------------------------
#
# Complete the `subset` functions to create three different vectors (`control`, `treat1` and `treat2`) that contain the weights of the yields under the three different conditions. If you have already done this step, you do not need to do it again.
#
# *Hint: I included the option `drop = TRUE` that indicates the results are saved to vectors as opposed to a data frame which will make our analysis easier in the next step.*
#
#
#
#
# ### Solution to Question 5c
#
# ------------------------------------------------------------------------
#
# <br>
# <br>

# %%
# subset the data into three separate vectors
control <- subset(PlantGrowth, group == "ctrl", select = weight, drop=TRUE)

treat1 <- subset(PlantGrowth, group == "trt1", select = weight, drop=TRUE)

treat2 <- subset(PlantGrowth, group == "trt2", select = weight, drop=TRUE)

# %% [markdown]
# ## <a name="HW9q5d">Question 5d</a>
#
# ------------------------------------------------------------------------
#
# Use the `t.test` function in R to construct a 90% confidence interval for the difference in the mean yield weights **between the control group and treatment group 1**. State the confidence interval, and then interpret the result. In particular, do you believe treatment 1 has made a difference in the yield weights of the plants? Explain why or why not.
#
# ### Solution to Question 5d
#
# ---
#
# Based on the output of the code cell below, write the confidence interval and interpret the results in the space below.
#
# The confidence interval is between -0.17 and 0.91; we can't conclude if treatment has made a difference based on this confidence interval because the interval includes 0.
#
# <br>
# <br>
# <br>

# %%
# use the t.test function to construct a 90% confidence interval
t.test(control, treat1, conf.level = 0.90)$conf.int
# Out:
# [1] -0.1716743  0.9136743
# attr(,"conf.level")
# [1] 0.9

# %% [markdown]
# ## <a name="HW9q5e">Question 5e</a>
#
# ------------------------------------------------------------------------
#
# Use the `t.test` function in R to construct a 90% confidence interval for the difference in the mean yield weights **between the control group and treatment group 2**. State the confidence interval, and then interpret the result. In particular, do you believe treatment 2 has made a difference in the yield weights of the plants? Explain why or why not.
#
# ### Solution to Question 5e
#
# ---
#
# Based on the output of the code cell below, write the confidence interval and interpret the results in the space below.
#
# The confidence interval is between -0.90 and -0.09; this interval doesn't include 0, so we can conclude that treatment 2 has increased the yield weights based on this confidence interval.
#
# <br>
# <br>
# <br>

# %%
# use the t.test function to construct a 90% confidence interval
t.test(control, treat2, conf.level = 0.90)
# Out:
# 	Welch Two Sample t-test
#
# data:  control and treat2
# t = -2.134, df = 16.786, p-value = 0.0479
# alternative hypothesis: true difference in means is not equal to 0
# 90 percent confidence interval:
#  -0.89699388 -0.09100612
# sample estimates:
# mean of x mean of y
#     5.032     5.526

# %% [markdown]
# ## <a name="HW9q5f">Question 5f</a>
#
# ------------------------------------------------------------------------
#
# Construct an approximate 90% confidence interval for the difference in the mean yield weights **between the control group and treatment group 2** by following the steps outlined below.
#
# -   Show your work by replacing each of the <mark>??</mark> below with an appropriate value.
#
# ### Solution to Question 5f
#
# ------------------------------------------------------------------------
#
# i.  The mean of the yield weight of the control group sample is <mark>5.03</mark> grams. The standard deviation of the yield weight of the control group sample is <mark>0.58</mark> grams.
#
# -   Round your answers to two decimal places when typing them above.

# %%
# enter commands to calculate and store the mean and standard deviation
# of the weight of the control group

ctrl.mean<- mean(control)
ctrl.sd<- sd(control)

ctrl.mean
ctrl.sd
# Out:
# [1] 5.032
# [1] 0.5830914

# %% [markdown]
# iI.  The mean of the yield weight of treatment group 2 sample is <mark>5.53</mark> grams. The standard deviation of the yield weight of treatment group 2 sample is <mark>0.44</mark> grams.
#
# -   Round your answers to two decimal places when typing them above.

# %%
# enter a command to calculate and store the mean and standard deviation
# of the weight of the treatment group 2

trt2.mean<- mean(treat2)
trt2.sd<- sd(treat2)

trt2.mean
trt2.sd
# Out:
# [1] 5.526
# [1] 0.4425733

# %% [markdown]
# iii. If we use the degrees of freedom of the $t$ distribution equal to the minimum of $n_1-1$ and $n_2-1$, the value of $t_{\alpha/2}$ for a 90% confidence interval is <mark>1.833</mark>.
#
# -   Round your answer to three decimal places when typing it above.

# %%
# Show work by entering a formula
df <- min(length(control), length(treat2)) - 1

# Calculate the t-value for a 90% confidence interval
t <- qt(0.95, df)

t
# Out:
# [1] 1.833113

# %% [markdown]
# iv. Using the previous answers in [Question 5f](#HW9q5f),a 90% confidence interval for thedifference in the mean yield weights of plants grown under the control conditions compared to treatment is from <mark>-0.918</mark> grams to <mark>-0.070</mark> grams.
#
# -   Round your answers to three decimal places when typing them above.

# %%
# Feel free to use code cell for calculations
lower_bound <- (ctrl.mean - trt2.mean) - (t * sqrt((ctrl.sd^2 / length(control)) + (trt2.sd^2 / length(treat2))))
upper_bound <- (ctrl.mean - trt2.mean) + (t * sqrt((ctrl.sd^2 / length(control)) + (trt2.sd^2 / length(treat2))))

# Output the confidence interval
lower_bound
upper_bound
# Out:
# [1] -0.9183435
# [1] -0.06965646

# %% [markdown]
# v.  How does your previous answer compare the to confidence interval you found in [Question 5e](#HW9q5e)? **Explain in a complete sentence or two.**
#
#
# It differs slightly - about 0.02 difference in the upper and lower. However, this is relatively insignicant because neither includes 0 in the interval, allowing us to make the same conclusion.
#
# <br>
# <br>

# %%
# Load the datasets package
library(datasets)

# Summary of the PlantGrowth data
summary(PlantGrowth)

# Question 5a: Create side-by-side boxplots
boxplot(weight ~ group,
        data = PlantGrowth,
        cex.lab = 1.5, cex.axis = 1.5, cex.main = 1.5)

# Question 5c: Subset the data into three separate vectors
control <- subset(PlantGrowth, group == "ctrl", select = weight, drop = TRUE)
treat1 <- subset(PlantGrowth, group == "trt1", select = weight, drop = TRUE)
treat2 <- subset(PlantGrowth, group == "trt2", select = weight, drop = TRUE)

# Question 5d: Construct a 90% confidence interval for control vs. treat1
t.test(control, treat1, conf.level = 0.90)$conf.int

# Question 5e: Construct a 90% confidence interval for control vs. treat2
t.test(control, treat2, conf.level = 0.90)$conf.int

# Question 5f: Construct an approximate 90% confidence interval for control vs. treat2
# Calculate means and standard deviations
ctrl_mean <- mean(control)
ctrl_sd <- sd(control)
trt2_mean <- mean(treat2)
trt2_sd <- sd(treat2)

# Calculate degrees of freedom and t-value
df <- min(length(control), length(treat2)) - 1
t <- qt(0.95, df)

# Calculate lower and upper bounds of the confidence interval
(ctrl_mean - trt2_mean) - (t * sqrt((ctrl_sd^2 / length(control)) + (trt2_sd^2 / length(treat2))))
(ctrl_mean - trt2_mean) + (t * sqrt((ctrl_sd^2 / length(control)) + (trt2_sd^2 / length(treat2))))
# Out:
#      weight       group
#  Min.   :3.590   ctrl:10
#  1st Qu.:4.550   trt1:10
#  Median :5.155   trt2:10
#  Mean   :5.073
#  3rd Qu.:5.530
#  Max.   :6.310
# [1] -0.1716743  0.9136743
# attr(,"conf.level")
# [1] 0.9
# [1] -0.89699388 -0.09100612
# attr(,"conf.level")
# [1] 0.9
# [1] -0.9183435
# [1] -0.06965646
# plot without title

# %% [markdown]
# # <a name="HWq6">Question 6</a>
#
# ------------------------------------------------------------------------
#
#
# Researchers conducted a study to help understand the impact of physical exercise on the stress levels of prisoners. The data set `PrisonStress` is in the `PairedData` package in R.
#
# - Run the first code cell to install the `PairedData` package.
#   - <mark>The first code cell may take 1-2 minutes to run. That is normal!</mark>
# - Run the second code cell load and display a summary of the `PrisonStress` data.

# %%
install.packages("PairedData")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘proxy’, ‘e1071’, ‘lmom’, ‘gld’, ‘mvtnorm’

# %%
library(PairedData)
data(PrisonStress)
summary(PrisonStress)
# Out:
# Loading required package: MASS
#
# Loading required package: gld
#
# Loading required package: mvtnorm
#
# Loading required package: lattice
#
# Loading required package: ggplot2
#
#
# Attaching package: ‘PairedData’
#
#
# The following object is masked from ‘package:base’:
#
#     summary
#     Subject       Group      PSSbefore        PSSafter
#  A1     : 1   Control:11   Min.   : 0.00   Min.   : 8.00
#  A2     : 1   Sport  :15   1st Qu.:15.50   1st Qu.:16.75
#  A3     : 1                Median :21.00   Median :21.50
#  A4     : 1                Mean   :20.73   Mean   :21.58
#  A5     : 1                3rd Qu.:27.00   3rd Qu.:26.75
#  A6     : 1                Max.   :44.00   Max.   :33.00
#  (Other):20

# %% [markdown]
# ## <a name="about-stress">About the Data</a>
#
# ---
#
# - This data set gives the [Perceived Stress Scale (PSS)](https://www.das.nh.gov/wellness/Docs%5CPercieved%20Stress%20Scale.pdf)
# which is a test used to measure stress levels.
# - A higher PSS score means higher stress level.
#
# - In total, there were 26 participants in the study.
#   - 15 prisoners participated in an exercise program.
#   - 11 prisoners did not complete an exercise program. They are the control group.
#
# - PSS scores were measured for each person at the start of the study and again for everyone after completion of the exercise training program.

# %% [markdown]
# ## <a name="HWq6a">Question 6a</a>
#
# ---
#
# The data set `PrisonStress` contains data from prisoners that took part in an exercise program (indicated with a `Group` class `Sport`), and prisoners in a control group that did not participate in the exercise program  (indicated with a `Group` class `Control`).
#
#
# Complete the `subset()` functions in the code cell below to create two separate data sets (each containing all the original variables) for each group:
#
# - One data frame containing data for only the prisoners that received the exercise treatment.
# - Another data frame for only the control group.
# - Both should contain all of the original variables in a data frame, which is why `drop = FALSE` is used.
#
#
# **Do not include a `select` option since we want to keep all variables when we subset.**
#
#
#
# ### Solution to Question 6a
#
# ------------------------------------------------------------------------
#
# Complete and run the code cell below.
#
# <br>
# <br>

# %%
# complete the command to subset the exercise group
exercise <- subset(PrisonStress, Group == "Sport", drop=FALSE)

# complete the command to subset the control group
none <- subset(PrisonStress, Group == "Control", drop=FALSE)

# %% [markdown]
# ## <a name="HWq6b">Question 6b</a>
#
# ------------------------------------------------------------------------
#
# **Using only data in the `exercise` data frame created in [Question 6a](#HWq6a)**, we will begin constructing a confidence interval to estimate the mean difference in PSS scores after completing the exercise program. **First we summarize the sample data of the exercise group.**
#
# Use the code cell below to calculate, store, and print the **sample mean and sample standard deviation of the matched-pair difference of PSS score for the prisoners in the exercise program**.
#
# - Be sure you store the results since you will need them later.
# - Be sure you print the results to the screen so you know their values.
#
#
# ### Solution to Question 6b
#
# ------------------------------------------------------------------------
#
# Complete and run the code cell below.
#
# <br>
# <br>

# %%
# calculate, store, and print the sample mean of the matched-pair differences
mean.ex<-mean(exercise$PSSafter  - exercise$PSSbefore)
mean.ex
# calculate, store, and print the sample standard deviation of the matched-pair differences
sd.ex<-sd(exercise$PSSafter  - exercise$PSSbefore)
sd.ex
# Out:
# [1] -3.933333
# [1] 5.675343

# %% [markdown]
# ## <a name="HW9q6c">Question 6c</a>
#
# ------------------------------------------------------------------------
#
# Construct a 99% confidence interval for the mean matched-pair difference in PSS score of prisoners that participate in the exercise program by completing the steps below.
#
# -   Show your work by replacing each <mark></mark> below with an appropriate value.
#
# ### Solution to Question 6b
#
# ------------------------------------------------------------------------
#
# <br>
#
# i.  An initial point estimate is $\mu_{\rm{diff}} \approx$ <mark>-3.933</mark>.
#
# <br>
#
# ii. The value of $z_{\alpha/2}$ or $t_{\alpha/2}$ (you decide which is appropriate) for a 99% confidence level is <mark>2.977</mark>.
#
# -   Round your answer to three decimal places when typing it above.

# %%
# Show work by entering a formula
t.ex<-qt(0.995, nrow(exercise) - 1)
t.ex
# Out:
# [1] 2.976843

# %% [markdown]
# <br>
#
# iii. The standard error of the underlying sampling distribution is <mark>4.362</mark>.
#
# -   Round your answer to three decimal places when typing it above.
#
# <br>

# %%
# Show work by entering a calculation
# that gives the standard error
err.ex<- sd.ex / sqrt(nrow(exercise)) * t.ex
err.ex
# Out:
# [1] 4.362168

# %% [markdown]
# <br>
#
# iv. The margin of error (MoE) for a 99% confidence interval is <mark>12.985</mark>.
#
# -   Round your answer to three decimal places when typing it above.
#
# <br>

# %%
# Show work by entering a calculation
# that gives the margin of error.
moe.ex<- t.ex * err.ex
moe.ex
# Out:
# [1] 12.98549

# %% [markdown]
# <br>
#
# v.  A 99% confidence interval for the mean difference in PSS score for prisoners that participate in the exercise program is from <mark>-16.919</mark> to <mark>9.052</mark>.
#
# -   Round your answers to three decimal places when typing them above.
#
# <br>

# %%
# Feel free to use code cell for calculations
mean.ex - moe.ex
mean.ex + moe.ex
# Out:
# [1] -16.91882
# [1] 9.052156

# %% [markdown]
# # <a name="HW9q7">Question 7</a>
#
# ------------------------------------------------------------------------
#
# In a recent survey of 5,593 US adults, 53% responded that they have an unfavorable opinion of the news media in the United States today<sup>1</sup>.
#
#
# In the questions below, we will use the data from this survey summarized above to construct and compare different 95% confidence intervals to estimate the proportion of all US adults that have an unfavorable opinion of the news media in the United States today.
#
#
# <br>
#
# <font size=2>1. ["American Views 2022: Part 2, Trust Media and Democracy"](https://knightfoundation.org/reports/american-views-2023-part-2/) Knight Foundation, February 25, 2023.</font>

# %% [markdown]
# ## <a name="HW9q7a">Question 7a</a>
#
# ------------------------------------------------------------------------
#
# Find a 95% confidence interval for the proportion of all adults in the US that have an unfavorable opinion of the news media in the US today **using the Wald confidence interval** for a proportion.
#
# ### Solution to Question 7a
#
# ------------------------------------------------------------------------
#
# <br>
#
# -   In addition to the R code and output from that code below, **be sure to type a sentence indicating your answer.**
# -   Do not leave it for your reader to interpret the output.
# -   **Round your answers to four decimal places when typing them.**
#
#
# The confidence interval is between 0.5169 and 0.5430.
#
# <br>
# <br>

# %%
# Enter calculations below.
# Feel free add code cells and break up calculations
# Into multiple code cells if you like
x<- 2964 / 5593

se<- qt(0.975, 5592) * sqrt(x * (1-x) / 5593)
se

x - se
x + se
# Out:
# [1] 0.01308306
# [1] 0.5168651
# [1] 0.5430312

# %% [markdown]
# ## <a name="HW9q7b">Question 7b</a>
#
# ------------------------------------------------------------------------
#
# Find a 95% confidence interval for the proportion of all adults in the US that have an unfavorable opinion of the news media in the US today **using the Agresti-Coull confidence interval** for a proportion.
#
# ### Solution to Question 7b
#
# ------------------------------------------------------------------------
#
# <br>
#
# -   In addition to the R code and output from that code below, **be sure to type a sentence indicating your answer.**
# -   Do not leave it for your reader to interpret the output.
# -   **Round your answers to four decimal places when typing them.**
#
# The interval is between 0.5168 and 0.5430.
#
#
# <br>
# <br>

# %%
# Enter calculations below.
# Feel free add code cells and break up calculations
# Into multiple code cells if you like
x<- 2966 / 5597

se<- qt(0.975, 5596) * sqrt(x * (1-x) / 5597)
se

x - se
x + se
# Out:
# [1] 0.01307841
# [1] 0.5168483
# [1] 0.5430052

# %% [markdown]
# ## <a name="HW9q7c">Question 7c</a>
#
# ------------------------------------------------------------------------
#
# Find a 95% confidence interval for the proportion of all adults in the US that have an unfavorable opinion of the news media in the US today **using the `prop.test` command** in R.
#
# ### Solution to Question 7c
#
# ------------------------------------------------------------------------
#
# <br>
#
# -   In addition to the R code and output from that code below, **be sure to type a sentence indicating your answer.**
# -   Do not leave it for your reader to interpret the output.
# -   **Round your answers to four decimal places when typing them.**
#
#
# The interval is between 0.5169 and 0.5430.
#
# <br>
# <br>

# %%
# Use prop test
prop.test(2964, 5593, conf.level = 0.95, correct = FALSE)$conf.int
# Out:
# [1] 0.5168518 0.5430033
# attr(,"conf.level")
# [1] 0.95

# %% [markdown]
# ## <a name="HW9q7d">Question 7d</a>
#
# ------------------------------------------------------------------------
#
# Which type of confidence interval for a proportion is computed using `prop.test` for a single proportion in [Question 7c](#HW9q7c)?
#
# - For example, it is not a Wald or Agresti-Coull confidence interval.
#
# ### Solution to Question 7d
#
# ------------------------------------------------------------------------
# prop.test is a Score Confidence Interval.
#
#
# <br>
# <br>

# %% [markdown]
# ## <a name="HW9q7e">Question 7e</a>
#
# ------------------------------------------------------------------------
#
# Rank the confidence intervals you found in [Question 7a](#HW9q7a), [Question 7b](#HW9q7b), and [Question 7c](#HW9q7c) from smallest to largest margin of error.
#
# ### Solution to Question 7e
#
# ------------------------------------------------------------------------
#
# -   The smallest margin of error is from part <mark>prop.test</mark>.
#
# -   The second smallest margin of error is from part <mark>Agresti Coull</mark>.
#
# -   The largest margin of error is from part <mark>Wald</mark>.

# %%
# Feel free to use code cell to help answer
# looked for thinnest/fattest interval
